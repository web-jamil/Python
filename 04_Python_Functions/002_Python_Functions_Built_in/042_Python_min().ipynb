# %% [markdown]
# <small><small><i>
# All the IPython Notebooks in this lecture series by Dr. Milan Parmar are available @ **[GitHub](https://github.com/milaan9/04_Python_Functions/tree/main/002_Python_Functions_Built_in)**
# </i></small></small>

# %% [markdown]
# # Python `min()`
#
# The Python **`min()`** function returns the smallest item in an iterable. It can also be used to find the smallest item between two or more parameters.
#
# **The `min()` function has two forms:**
#
# ```python
# // to find the smallest item in an iterable
# min(iterable, *iterables, key, default)
#
# // to find the smallest item between two or more objects
# min(arg1, arg2, *args, key)
# ```

# %% [markdown]
# ## 1. `min()` with iterable arguments
#
# To find the largest item in an iterable, we use this syntax:
#
# ```python
# min(iterable, *iterables, key, default)
# ```

# %% [markdown]
# ## `min()` Parameters
#
# - **iterable** - an iterable such as list, tuple, set, dictionary, etc.
# - **\*iterables** (optional) - any number of iterables; can be more than one
# - **key (optional)** - key function where the iterables are passed and comparison is performed based on its return value
# - **default (optional)** - default value if the given iterable is empty

# %%
# Example 1: Get the smallest item in a list

number = [3, 2, 8, 5, 10, 6]
largest_number = min(number);

print("The smallest number is:", largest_number)
# Out:
# The smallest number is: 2

# %% [markdown]
# If the items in an iterable are strings, the smallest item (ordered alphabetically) is returned.

# %%
# Example 2: the smallest string in a list

languages = ["Python", "C Programming", "Java", "JavaScript"]
largest_string = min(languages);

print("The smallest string is:", largest_string)
# Out:
# The smallest string is: C Programming

# %% [markdown]
# In the case of dictionaries, **`min()`** returns the largest key. Let's use the **`key`** parameter so that we can find the dictionary's key having the largest value.

# %%
# Example 3: min() in dictionaries

square = {2: 4, -3: 9, -1: 1, -2: 4}

# the largest key
key1 = min(square)
print("The largest key:", key1)    # 2

# the key whose value is the largest
key2 = min(square, key = lambda k: square[k])

print("The key with the smallest value:", key2)    # -3

# getting the largest value
print("The largest value:", square[key2])    # 9
# Out:
# The largest key: -3
# The key with the smallest value: -1
# The largest value: 1

# %% [markdown]
# In the second **`min()`** function, we have passed a **[lambda function](https://github.com/milaan9/04_Python_Functions/blob/main/006_Python_Function_Anonymous.ipynb)** to the **`key`** parameter.
#
# ```python
# key = lambda k: square[k]
# ```
#
# The function returns the values of dictionaries. Based on the values (rather than the dictionary's keys), the key having the maximum value is returned.

# %% [markdown]
# > Few Notes:
#
# - If we pass an empty iterator, a **`ValueError`** exception is raised. To avoid this, we can pass the **`default`** parameter.
# - If we pass more than one iterators, the smallest item from the given iterators is returned.

# %% [markdown]
# ## 2. `min()` without iterable
#
# To find the smallest object between two or more parameters, we can use this syntax:
#
# ```python
# min(arg1, arg2, *args, key)
# ```

# %% [markdown]
# ## `min()` Parameters
#
# - **arg1** - an object; can be numbers, strings, etc.
# - **arg2** - an object; can be numbers, strings, etc.
# - **\*args (optional)** - any number of objects
# - **key (optional)** - key function where each argument is passed, and comparison is performed based on its return value
#
# Basically, the **`min()`** function finds the smallest item between two or more objects.

# %%
# Example 4: Find the minimum among the given numbers

result = min(4, -5, 23, 5)
print("The minimum number is:", result)
# Out:
# The minimum number is: -5

# %% [markdown]
# If you need to find the smallest item, you can use the **[Python max()](https://github.com/milaan9/04_Python_Functions/blob/main/002_Python_Functions_Built_in/041_Python_max%28%29.ipynb)** function.

# %% [markdown]
# The `min()` function in Python is a built-in function used to **find the smallest item** in an iterable or among multiple arguments. It is a versatile function that works with various data types, including numbers, strings, and custom objects. Below is a comprehensive guide to the `min()` function, covering everything from basic to advanced usage.
#
# ---
#
# ## **Table of Contents**
#
# 1. **Basics of `min()`**
#    - Finding the Minimum in an Iterable
#    - Finding the Minimum Among Multiple Arguments
# 2. **Advanced Usage of `min()`**
#    - Using the `key` Parameter
#    - Handling Empty Iterables
#    - Comparing Strings and Custom Objects
# 3. **Practical Use Cases**
#    - Finding the Smallest Number
#    - Finding the Shortest String
#    - Finding the Minimum in a List of Tuples
# 4. **Advanced Topics**
#    - Combining `min()` with `lambda`
#    - Using `min()` with `default`
#    - Performance Considerations
#
# ---
#
# ## **1. Basics of `min()`**
#
# ### **Finding the Minimum in an Iterable**
#
# The `min()` function can take an iterable (e.g., list, tuple, set) and return the smallest item.
#
# ```python
# # Example 1: List of numbers
# numbers = [3, 1, 4, 1, 5, 9]
# print(min(numbers))  # Output: 1
#
# # Example 2: Tuple of strings
# fruits = ("apple", "banana", "cherry")
# print(min(fruits))  # Output: 'apple' (alphabetical order)
# ```
#
# ### **Finding the Minimum Among Multiple Arguments**
#
# You can also pass multiple arguments to `min()` to find the smallest one.
#
# ```python
# # Example: Find the smallest among multiple numbers
# print(min(3, 1, 4, 1, 5, 9))  # Output: 1
# ```
#
# ---
#
# ## **2. Advanced Usage of `min()`**
#
# ### **Using the `key` Parameter**
#
# The `key` parameter allows you to specify a function to customize the comparison logic.
#
# ```python
# # Example 1: Find the shortest string based on length
# fruits = ["apple", "banana", "cherry"]
# print(min(fruits, key=len))  # Output: 'apple'
#
# # Example 2: Find the tuple with the smallest second element
# tuples = [(1, 2), (3, 1), (5, 0)]
# print(min(tuples, key=lambda x: x[1]))  # Output: (5, 0)
# ```
#
# ### **Handling Empty Iterables**
#
# If the iterable is empty, `min()` raises a `ValueError`. You can handle this by providing a `default` value.
#
# ```python
# # Example: Handle empty iterable with default value
# empty_list = []
# print(min(empty_list, default="No elements"))  # Output: 'No elements'
# ```
#
# ### **Comparing Strings and Custom Objects**
#
# `min()` works with strings (lexicographical order) and custom objects (if they support comparison).
#
# ```python
# # Example 1: Compare strings
# words = ["apple", "banana", "cherry"]
# print(min(words))  # Output: 'apple'
#
# # Example 2: Compare custom objects
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def __lt__(self, other):
#         return self.age < other.age
#
# people = [Person("Alice", 25), Person("Bob", 20), Person("Charlie", 30)]
# print(min(people, key=lambda p: p.age).name)  # Output: 'Bob'
# ```
#
# ---
#
# ## **3. Practical Use Cases**
#
# ### **Finding the Smallest Number**
#
# Use `min()` to find the smallest number in a list.
#
# ```python
# numbers = [3, 1, 4, 1, 5, 9]
# print(min(numbers))  # Output: 1
# ```
#
# ### **Finding the Shortest String**
#
# Use `min()` with the `key` parameter to find the shortest string.
#
# ```python
# fruits = ["apple", "banana", "cherry"]
# print(min(fruits, key=len))  # Output: 'apple'
# ```
#
# ### **Finding the Minimum in a List of Tuples**
#
# Use `min()` with a custom key to find the minimum based on a specific element in a tuple.
#
# ```python
# tuples = [(1, 2), (3, 1), (5, 0)]
# print(min(tuples, key=lambda x: x[1]))  # Output: (5, 0)
# ```
#
# ---
#
# ## **4. Advanced Topics**
#
# ### **Combining `min()` with `lambda`**
#
# You can use `lambda` functions with `min()` for more complex comparisons.
#
# ```python
# # Example: Find the string with the smallest ASCII value of the first character
# fruits = ["apple", "banana", "cherry"]
# print(min(fruits, key=lambda x: ord(x[0])))  # Output: 'apple'
# ```
#
# ### **Using `min()` with `default`**
#
# The `default` parameter allows you to specify a value to return if the iterable is empty.
#
# ```python
# # Example: Handle empty iterable with default value
# empty_list = []
# print(min(empty_list, default="No elements"))  # Output: 'No elements'
# ```
#
# ### **Performance Considerations**
#
# - `min()` has a time complexity of **O(n)**, where `n` is the number of elements in the iterable.
# - It is efficient for most use cases but can be optimized further for large datasets using libraries like `numpy`.
#
# ---
#
# ## **Summary**
#
# | Feature                      | Example                                            |
# | ---------------------------- | -------------------------------------------------- |
# | Find minimum in iterable     | `min([3, 1, 4, 1, 5, 9])` → `1`                    |
# | Find minimum among arguments | `min(3, 1, 4, 1, 5, 9)` → `1`                      |
# | Use `key` parameter          | `min(fruits, key=len)` → `'apple'`                 |
# | Handle empty iterable        | `min([], default="No elements")` → `'No elements'` |
# | Compare custom objects       | `min(people, key=lambda p: p.age)` → `'Bob'`       |
#
# ---
#
# This covers everything from basic to advanced usage of the `min()` function in Python. Let me know if you have further questions!
