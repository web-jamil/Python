# %% [markdown]
# <small><small><i>
# All the IPython Notebooks in this lecture series by Dr. Milan Parmar are available @ **[GitHub](https://github.com/milaan9/04_Python_Functions/tree/main/002_Python_Functions_Built_in)**
# </i></small></small>

# %% [markdown]
# # Python `set()`
#
# The **`set()`** builtin creates a set in Python.
#
# **Syntax**:
#
# ```python
# set(iterable)
# ```
#
# > Recommended Reading: **[Python sets](https://github.com/milaan9/02_Python_Datatypes/blob/main/006_Python_Sets.ipynb)**

# %% [markdown]
# ## `set()` Parameters
#
# **`set()`** takes a single optional parameter:
#
# - **iterable (optional)** - a sequence (**[string](https://github.com/milaan9/02_Python_Datatypes/blob/main/002_Python_String.ipynb)**, **[tuple](https://github.com/milaan9/02_Python_Datatypes/blob/main/004_Python_Tuple.ipynb)**, etc.) or collection (**[set](https://github.com/milaan9/02_Python_Datatypes/blob/main/006_Python_Sets.ipynb)**, **[dictionary](https://github.com/milaan9/02_Python_Datatypes/blob/main/005_Python_Dictionary.ipynb)**, etc.) or an iterator object to be converted into a set.

# %% [markdown]
# ## Return Value from `set()`
#
# **`set()`** returns:
#
# - an empty set if no parameters are passed
# - a set constructed from the given **iterable** parameter

# %%
# Example 1: Create sets from string, tuple, list, and range

# empty set
print(set())

# from string
print(set('Python'))

# from tuple
print(set(('a', 'e', 'i', 'o', 'u')))

# from list
print(set(['a', 'e', 'i', 'o', 'u']))

# from range
print(set(range(5)))
# Out:
# set()
# {'P', 't', 'o', 'y', 'h', 'n'}
# {'e', 'u', 'o', 'a', 'i'}
# {'e', 'u', 'o', 'a', 'i'}
# {0, 1, 2, 3, 4}

# %% [markdown]
# > **Note:** We cannot create empty sets using **`{ }`** syntax as it creates an empty dictionary. To create an empty set, we use **`set()`**.

# %%
# Example 2: Create sets from another set, dictionary and frozen set

# from set
print(set({'a', 'e', 'i', 'o', 'u'}))

# from dictionary
print(set({'a':1, 'e': 2, 'i':3, 'o':4, 'u':5}))

# from frozen set
frozen_set = frozenset(('a', 'e', 'i', 'o', 'u'))
print(set(frozen_set))
# Out:
# {'e', 'i', 'u', 'o', 'a'}
# {'e', 'i', 'u', 'o', 'a'}
# {'e', 'i', 'u', 'o', 'a'}

# %%
# Example 3: Create set() for a custom iterable object

class PrintNumber:
    def __init__(self, max):
        self.max = max

    def __iter__(self):
        self.num = 0
        return self

    def __next__(self):
        if(self.num >= self.max):
            raise StopIteration
        self.num += 1
        return self.num

# print_num is an iterable
print_num = PrintNumber(5)

# creating a set
print(set(print_num))
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Sets in Python are a powerful and versatile data structure that store **unique, unordered, and mutable** collections of elements. They are particularly useful for tasks involving membership testing, removing duplicates, and performing mathematical set operations like unions, intersections, and differences. Below is a comprehensive guide to Python sets, from basic to advanced usage.
#
# ---
#
# ## **Table of Contents**
#
# 1. **Basics of Sets**
#    - Creating Sets
#    - Characteristics of Sets
#    - Adding and Removing Elements
# 2. **Set Operations**
#    - Union
#    - Intersection
#    - Difference
#    - Symmetric Difference
# 3. **Set Methods**
#    - Common Methods
#    - Advanced Methods
# 4. **Frozen Sets**
# 5. **Set Comprehensions**
# 6. **Performance and Use Cases**
# 7. **Advanced Topics**
#    - Set Operations with Other Data Types
#    - Custom Objects in Sets
#    - Set Memory Management
#
# ---
#
# ## **1. Basics of Sets**
#
# ### **Creating Sets**
#
# Sets are created using curly braces `{}` or the `set()` constructor.
#
# ```python
# # Using curly braces
# my_set = {1, 2, 3, 4, 5}
# print(my_set)  # Output: {1, 2, 3, 4, 5}
#
# # Using set() constructor
# my_set = set([1, 2, 3, 4, 5])
# print(my_set)  # Output: {1, 2, 3, 4, 5}
#
# # Empty set (use set(), not {})
# empty_set = set()
# print(empty_set)  # Output: set()
# ```
#
# ### **Characteristics of Sets**
#
# - **Unordered**: Sets do not maintain the order of elements.
# - **Unique Elements**: Duplicates are automatically removed.
# - **Mutable**: You can add or remove elements.
# - **Heterogeneous**: Sets can contain different data types (e.g., integers, strings, tuples).
#
# ```python
# my_set = {1, 2, 2, 3, "hello", (4, 5)}
# print(my_set)  # Output: {1, 2, 3, 'hello', (4, 5)}
# ```
#
# ### **Adding and Removing Elements**
#
# - **Add an element**: Use the `add()` method.
# - **Remove an element**: Use `remove()` or `discard()`.
#   - `remove()` raises an error if the element is not found.
#   - `discard()` does not raise an error.
# - **Clear all elements**: Use `clear()`.
#
# ```python
# my_set = {1, 2, 3}
#
# # Add an element
# my_set.add(4)
# print(my_set)  # Output: {1, 2, 3, 4}
#
# # Remove an element
# my_set.remove(2)
# print(my_set)  # Output: {1, 3, 4}
#
# # Discard an element (no error if not found)
# my_set.discard(5)
# print(my_set)  # Output: {1, 3, 4}
#
# # Clear all elements
# my_set.clear()
# print(my_set)  # Output: set()
# ```
#
# ---
#
# ## **2. Set Operations**
#
# Sets support mathematical operations like union, intersection, difference, and symmetric difference.
#
# ### **Union (`|` or `union()`)**
#
# Combines elements from two sets, removing duplicates.
#
# ```python
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
#
# # Using | operator
# union_set = set1 | set2
# print(union_set)  # Output: {1, 2, 3, 4, 5}
#
# # Using union() method
# union_set = set1.union(set2)
# print(union_set)  # Output: {1, 2, 3, 4, 5}
# ```
#
# ### **Intersection (`&` or `intersection()`)**
#
# Returns elements common to both sets.
#
# ```python
# # Using & operator
# intersection_set = set1 & set2
# print(intersection_set)  # Output: {3}
#
# # Using intersection() method
# intersection_set = set1.intersection(set2)
# print(intersection_set)  # Output: {3}
# ```
#
# ### **Difference (`-` or `difference()`)**
#
# Returns elements in the first set that are not in the second set.
#
# ```python
# # Using - operator
# difference_set = set1 - set2
# print(difference_set)  # Output: {1, 2}
#
# # Using difference() method
# difference_set = set1.difference(set2)
# print(difference_set)  # Output: {1, 2}
# ```
#
# ### **Symmetric Difference (`^` or `symmetric_difference()`)**
#
# Returns elements that are in either set but not in both.
#
# ```python
# # Using ^ operator
# symmetric_diff_set = set1 ^ set2
# print(symmetric_diff_set)  # Output: {1, 2, 4, 5}
#
# # Using symmetric_difference() method
# symmetric_diff_set = set1.symmetric_difference(set2)
# print(symmetric_diff_set)  # Output: {1, 2, 4, 5}
# ```
#
# ---
#
# ## **3. Set Methods**
#
# ### **Common Methods**
#
# - `add()`: Adds an element.
# - `remove()`: Removes an element (raises error if not found).
# - `discard()`: Removes an element (no error if not found).
# - `pop()`: Removes and returns an arbitrary element.
# - `clear()`: Removes all elements.
# - `copy()`: Returns a shallow copy of the set.
#
# ### **Advanced Methods**
#
# - `update()`: Adds multiple elements (like union but in-place).
# - `intersection_update()`: Updates the set with the intersection.
# - `difference_update()`: Updates the set with the difference.
# - `symmetric_difference_update()`: Updates the set with the symmetric difference.
# - `isdisjoint()`: Checks if two sets have no common elements.
# - `issubset()`: Checks if a set is a subset of another.
# - `issuperset()`: Checks if a set is a superset of another.
#
# ```python
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
#
# # Update
# set1.update(set2)
# print(set1)  # Output: {1, 2, 3, 4, 5}
#
# # Intersection Update
# set1.intersection_update(set2)
# print(set1)  # Output: {3, 4, 5}
#
# # Check if disjoint
# print(set1.isdisjoint({6, 7}))  # Output: True
#
# # Check if subset
# print({1, 2}.issubset({1, 2, 3}))  # Output: True
# ```
#
# ---
#
# ## **4. Frozen Sets**
#
# Frozen sets are immutable versions of sets. They are created using the `frozenset()` constructor.
#
# ```python
# frozen_set = frozenset([1, 2, 3])
# print(frozen_set)  # Output: frozenset({1, 2, 3})
#
# # Frozen sets are immutable
# # frozen_set.add(4)  # Raises AttributeError
# ```
#
# ---
#
# ## **5. Set Comprehensions**
#
# Set comprehensions allow you to create sets using a concise syntax.
#
# ```python
# squares = {x ** 2 for x in range(5)}
# print(squares)  # Output: {0, 1, 4, 9, 16}
# ```
#
# ---
#
# ## **6. Performance and Use Cases**
#
# - **Membership Testing**: Sets are optimized for checking if an element exists (`O(1)` average time complexity).
# - **Removing Duplicates**: Convert a list to a set to remove duplicates.
# - **Mathematical Operations**: Use sets for unions, intersections, etc.
#
# ---
#
# ## **7. Advanced Topics**
#
# ### **Set Operations with Other Data Types**
#
# Sets can interact with lists, tuples, and dictionaries.
#
# ```python
# # Convert list to set to remove duplicates
# my_list = [1, 2, 2, 3, 4]
# unique_elements = set(my_list)
# print(unique_elements)  # Output: {1, 2, 3, 4}
#
# # Set operations with dictionary keys
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}
# keys_set = set(dict1.keys()) | set(dict2.keys())
# print(keys_set)  # Output: {'a', 'b', 'c'}
# ```
#
# ### **Custom Objects in Sets**
#
# To store custom objects in sets, ensure they are hashable (implement `__hash__` and `__eq__`).
#
# ```python
# class Person:
#     def __init__(self, name):
#         self.name = name
#
#     def __hash__(self):
#         return hash(self.name)
#
#     def __eq__(self, other):
#         return self.name == other.name
#
# person_set = {Person("Alice"), Person("Bob")}
# print(person_set)  # Output: {<__main__.Person object at ...>, <__main__.Person object at ...>}
# ```
#
# ### **Set Memory Management**
#
# Sets use hash tables internally, which makes them memory-efficient for large datasets.
#
# ---
#
# ## **Summary**
#
# | Feature              | Example                                            |
# | -------------------- | -------------------------------------------------- | ------------------------- |
# | Create a set         | `my_set = {1, 2, 3}`                               |
# | Add an element       | `my_set.add(4)`                                    |
# | Remove an element    | `my_set.remove(2)`                                 |
# | Union                | `set1                                              | set2`or`set1.union(set2)` |
# | Intersection         | `set1 & set2` or `set1.intersection(set2)`         |
# | Difference           | `set1 - set2` or `set1.difference(set2)`           |
# | Symmetric Difference | `set1 ^ set2` or `set1.symmetric_difference(set2)` |
# | Frozen Set           | `frozenset([1, 2, 3])`                             |
# | Set Comprehension    | `{x ** 2 for x in range(5)}`                       |
#
# ---
#
# This covers everything from basic to advanced usage of sets in Python. Let me know if you have further questions!
