# %% [markdown]
# The `collections` module in Python is a powerful module that provides specialized container data types as alternatives to the built-in containers like `list`, `dict`, `set`, and `tuple`. These specialized containers are designed to be more efficient and convenient for specific use cases. Below is a comprehensive guide to the `collections` module, covering everything from basic to advanced usage.
#
# ---
#
# ### **1. Overview of `collections` Module**
#
# The `collections` module includes the following data structures:
#
# - `namedtuple`: Creates tuple-like objects with named fields.
# - `deque`: A double-ended queue for fast appends and pops.
# - `ChainMap`: Combines multiple dictionaries into a single view.
# - `Counter`: Counts hashable objects.
# - `OrderedDict`: A dictionary that maintains insertion order.
# - `defaultdict`: A dictionary with default values for missing keys.
# - `UserDict`, `UserList`, `UserString`: Wrapper classes for creating custom dictionary, list, and string-like objects.
#
# ---
#
# ### **2. `namedtuple`**
#
# A `namedtuple` is a subclass of a tuple with named fields. It is immutable and memory-efficient.
#
# #### **Basic Usage**
#
# ```python
# from collections import namedtuple
#
# # Define a namedtuple
# Point = namedtuple('Point', ['x', 'y'])
#
# # Create an instance
# p = Point(10, 20)
#
# # Access fields
# print(p.x)  # Output: 10
# print(p.y)  # Output: 20
# ```
#
# #### **Advanced Usage**
#
# - Use `_asdict()` to convert to a dictionary.
# - Use `_replace()` to create a new instance with updated values.
#
# ```python
# # Convert to dictionary
# print(p._asdict())  # Output: {'x': 10, 'y': 20}
#
# # Replace a value
# p_new = p._replace(x=15)
# print(p_new)  # Output: Point(x=15, y=20)
# ```
#
# ---
#
# ### **3. `deque`**
#
# A `deque` (double-ended queue) is optimized for fast appends and pops from both ends.
#
# #### **Basic Usage**
#
# ```python
# from collections import deque
#
# # Create a deque
# d = deque([1, 2, 3])
#
# # Append to the right
# d.append(4)  # deque([1, 2, 3, 4])
#
# # Append to the left
# d.appendleft(0)  # deque([0, 1, 2, 3, 4])
#
# # Pop from the right
# d.pop()  # Returns 4, deque([0, 1, 2, 3])
#
# # Pop from the left
# d.popleft()  # Returns 0, deque([1, 2, 3])
# ```
#
# #### **Advanced Usage**
#
# - Use `maxlen` to create a fixed-size deque.
# - Use `rotate()` to shift elements.
#
# ```python
# # Fixed-size deque
# d = deque(maxlen=3)
# d.extend([1, 2, 3])
# d.append(4)  # deque([2, 3, 4])
#
# # Rotate elements
# d.rotate(1)  # deque([4, 2, 3])
# ```
#
# ---
#
# ### **4. `ChainMap`**
#
# A `ChainMap` groups multiple dictionaries into a single view. Lookups search the underlying dictionaries sequentially.
#
# #### **Basic Usage**
#
# ```python
# from collections import ChainMap
#
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}
#
# # Create a ChainMap
# chain = ChainMap(dict1, dict2)
#
# # Access values
# print(chain['a'])  # Output: 1 (from dict1)
# print(chain['b'])  # Output: 2 (from dict1, first match)
# print(chain['c'])  # Output: 4 (from dict2)
# ```
#
# #### **Advanced Usage**
#
# - Use `new_child()` to add a new dictionary to the beginning.
# - Use `maps` to access the underlying dictionaries.
#
# ```python
# # Add a new dictionary
# dict3 = {'d': 5}
# chain = chain.new_child(dict3)
#
# # Access underlying dictionaries
# print(chain.maps)  # Output: [{'d': 5}, {'a': 1, 'b': 2}, {'b': 3, 'c': 4}]
# ```
#
# ---
#
# ### **5. `Counter`**
#
# A `Counter` is a dictionary subclass for counting hashable objects.
#
# #### **Basic Usage**
#
# ```python
# from collections import Counter
#
# # Create a Counter
# c = Counter(['a', 'b', 'a', 'c', 'b', 'a'])
#
# # Access counts
# print(c['a'])  # Output: 3
# print(c['b'])  # Output: 2
# ```
#
# #### **Advanced Usage**
#
# - Use `most_common()` to get the most frequent elements.
# - Use arithmetic operations like `+`, `-`, `&`, `|`.
#
# ```python
# # Most common elements
# print(c.most_common(2))  # Output: [('a', 3), ('b', 2)]
#
# # Arithmetic operations
# c1 = Counter(a=3, b=1)
# c2 = Counter(a=1, b=2)
# print(c1 + c2)  # Output: Counter({'a': 4, 'b': 3})
# ```
#
# ---
#
# ### **6. `OrderedDict`**
#
# An `OrderedDict` maintains the insertion order of keys.
#
# #### **Basic Usage**
#
# ```python
# from collections import OrderedDict
#
# # Create an OrderedDict
# od = OrderedDict()
# od['a'] = 1
# od['b'] = 2
# od['c'] = 3
#
# # Iterate in insertion order
# for key, value in od.items():
#     print(key, value)  # Output: a 1, b 2, c 3
# ```
#
# #### **Advanced Usage**
#
# - Use `move_to_end()` to move a key to the beginning or end.
# - Use `popitem()` to remove and return the last or first item.
#
# ```python
# # Move 'b' to the end
# od.move_to_end('b')
# print(od)  # Output: OrderedDict([('a', 1), ('c', 3), ('b', 2)])
#
# # Pop the last item
# od.popitem(last=True)  # Returns ('b', 2)
# ```
#
# ---
#
# ### **7. `defaultdict`**
#
# A `defaultdict` provides default values for missing keys.
#
# #### **Basic Usage**
#
# ```python
# from collections import defaultdict
#
# # Create a defaultdict with default value 0
# dd = defaultdict(int)
# dd['a'] += 1
#
# print(dd['a'])  # Output: 1
# print(dd['b'])  # Output: 0 (default value)
# ```
#
# #### **Advanced Usage**
#
# - Use a lambda function to specify custom default values.
#
# ```python
# # Custom default value
# dd = defaultdict(lambda: 'unknown')
# print(dd['a'])  # Output: 'unknown'
# ```
#
# ---
#
# ### **8. `UserDict`, `UserList`, `UserString`**
#
# These are wrapper classes for creating custom dictionary, list, and string-like objects.
#
# #### **Basic Usage**
#
# ```python
# from collections import UserDict
#
# # Create a custom dictionary
# class MyDict(UserDict):
#     def __missing__(self, key):
#         return 'default'
#
# md = MyDict({'a': 1})
# print(md['a'])  # Output: 1
# print(md['b'])  # Output: 'default'
# ```
#
# ---
#
# ### **9. Practical Use Cases**
#
# - **`Counter`**: Counting occurrences of elements in a list.
# - **`defaultdict`**: Grouping items in a dictionary.
# - **`deque`**: Implementing queues or stacks.
# - **`namedtuple`**: Creating lightweight, immutable data structures.
# - **`ChainMap`**: Managing configuration settings with fallbacks.
#
# ---
#
# ### **10. Summary**
#
# The `collections` module provides specialized data structures that are more efficient and convenient than built-in containers for specific tasks. By mastering these tools, you can write cleaner, more efficient, and more Pythonic code.
#
# The `collections` module in Python is a powerful built-in module that provides specialized container data types as alternatives to the general-purpose built-in containers like `list`, `tuple`, `dict`, and `set`. These specialized data structures are designed to handle specific use cases more efficiently and conveniently.
#
# Below is a comprehensive guide to the `collections` module, covering everything from basic to advanced concepts:
#
# ---
#
# ### **1. Overview of `collections` Module**
#
# The `collections` module includes the following data structures:
#
# - `Counter`
# - `defaultdict`
# - `OrderedDict`
# - `deque`
# - `ChainMap`
# - `namedtuple`
# - `UserDict`, `UserList`, `UserString` (for creating custom containers)
#
# ---
#
# ### **2. `Counter`**
#
# A `Counter` is a subclass of `dict` designed for counting hashable objects. It is a collection where elements are stored as dictionary keys, and their counts are stored as dictionary values.
#
# #### **Basic Usage**
#
# ```python
# from collections import Counter
#
# # Counting elements in a list
# data = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
# counter = Counter(data)
# print(counter)  # Output: Counter({'apple': 3, 'banana': 2, 'orange': 1})
#
# # Most common elements
# print(counter.most_common(2))  # Output: [('apple', 3), ('banana', 2)]
# ```
#
# #### **Advanced Features**
#
# - Arithmetic operations: `+`, `-`, `&`, `|`
# - Update counts: `counter.update(new_data)`
# - Subtract counts: `counter.subtract(new_data)`
#
# ---
#
# ### **3. `defaultdict`**
#
# A `defaultdict` is a subclass of `dict` that provides a default value for missing keys. It avoids `KeyError` by automatically initializing keys with a default value.
#
# #### **Basic Usage**
#
# ```python
# from collections import defaultdict
#
# # Default value as int
# count = defaultdict(int)
# count['apple'] += 1
# print(count)  # Output: defaultdict(<class 'int'>, {'apple': 1})
#
# # Default value as list
# grouped_data = defaultdict(list)
# grouped_data['fruits'].append('apple')
# print(grouped_data)  # Output: defaultdict(<class 'list'>, {'fruits': ['apple']})
# ```
#
# #### **Advanced Features**
#
# - Custom default factories (e.g., `lambda` functions)
# - Nested `defaultdict` for hierarchical data structures.
#
# ---
#
# ### **4. `OrderedDict`**
#
# An `OrderedDict` is a subclass of `dict` that maintains the order of keys as they are inserted. In Python 3.7+, the built-in `dict` also maintains insertion order, but `OrderedDict` provides additional methods.
#
# #### **Basic Usage**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict()
# od['a'] = 1
# od['b'] = 2
# od['c'] = 3
# print(od)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3)])
#
# # Reordering keys
# od.move_to_end('a')
# print(od)  # Output: OrderedDict([('b', 2), ('c', 3), ('a', 1)])
# ```
#
# #### **Advanced Features**
#
# - `popitem(last=True|False)`: Remove and return the last/first item.
# - `move_to_end(key, last=True|False)`: Move a key to the end or beginning.
#
# ---
#
# ### **5. `deque`**
#
# A `deque` (double-ended queue) is a list-like container with fast appends and pops from both ends. It is optimized for operations at both ends.
#
# #### **Basic Usage**
#
# ```python
# from collections import deque
#
# d = deque([1, 2, 3])
# d.append(4)  # Add to the right
# d.appendleft(0)  # Add to the left
# print(d)  # Output: deque([0, 1, 2, 3, 4])
#
# d.pop()  # Remove from the right
# d.popleft()  # Remove from the left
# print(d)  # Output: deque([1, 2, 3])
# ```
#
# #### **Advanced Features**
#
# - Fixed-size deque: `deque(maxlen=5)`
# - Rotate elements: `d.rotate(2)`
# - Thread-safe operations.
#
# ---
#
# ### **6. `ChainMap`**
#
# A `ChainMap` groups multiple dictionaries or mappings into a single, updateable view. It is useful for combining configurations or searching through multiple dictionaries.
#
# #### **Basic Usage**
#
# ```python
# from collections import ChainMap
#
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}
# chain = ChainMap(dict1, dict2)
#
# print(chain['a'])  # Output: 1 (from dict1)
# print(chain['b'])  # Output: 2 (from dict1, first match)
# print(chain['c'])  # Output: 4 (from dict2)
# ```
#
# #### **Advanced Features**
#
# - Adding new mappings: `chain.new_child(dict3)`
# - Updating mappings: `chain.maps[0]['a'] = 10`
#
# ---
#
# ### **7. `namedtuple`**
#
# A `namedtuple` is a factory function for creating tuple subclasses with named fields. It makes code more readable and self-documenting.
#
# #### **Basic Usage**
#
# ```python
# from collections import namedtuple
#
# Point = namedtuple('Point', ['x', 'y'])
# p = Point(10, 20)
# print(p.x, p.y)  # Output: 10 20
# print(p[0], p[1])  # Output: 10 20 (still accessible by index)
# ```
#
# #### **Advanced Features**
#
# - Default values: `namedtuple('Point', ['x', 'y'], defaults=[0, 0])`
# - Immutable but memory-efficient.
#
# ---
#
# ### **8. `UserDict`, `UserList`, `UserString`**
#
# These are wrapper classes for creating custom dictionary-like, list-like, or string-like objects. They are useful for subclassing and extending functionality.
#
# #### **Basic Usage**
#
# ```python
# from collections import UserDict
#
# class MyDict(UserDict):
#     def __setitem__(self, key, value):
#         super().__setitem__(key, value * 2)
#
# d = MyDict()
# d['a'] = 1
# print(d)  # Output: {'a': 2}
# ```
#
# ---
#
# ### **9. Practical Use Cases**
#
# - **`Counter`**: Word frequency analysis, inventory management.
# - **`defaultdict`**: Grouping data, handling missing keys.
# - **`OrderedDict`**: Maintaining insertion order (e.g., LRU cache).
# - **`deque`**: Implementing queues, stacks, or sliding windows.
# - **`ChainMap`**: Managing configurations or layered data.
# - **`namedtuple`**: Representing records or data points.
#
# ---
#
# ### **10. Performance Considerations**
#
# - `Counter` is optimized for counting operations.
# - `deque` provides O(1) complexity for append/pop operations at both ends.
# - `defaultdict` avoids `KeyError` but adds a slight overhead for default value initialization.
#
# ---
#
# ### **11. Summary**
#
# The `collections` module is a versatile tool for handling specialized data structures in Python. By leveraging these containers, you can write more efficient, readable, and maintainable code. Each data structure is designed to solve specific problems, so choose the one that best fits your use case.
#
# The `collections` module in Python is a powerful built-in module that provides specialized container data types as alternatives to the general-purpose built-in containers like `list`, `dict`, `set`, and `tuple`. These specialized data structures are designed to handle specific use cases more efficiently and with more functionality.
#
# Here’s a comprehensive guide to the `collections` module, from basic to advanced:
#
# ---
#
# ### **1. Basic Collections**
#
# These are the most commonly used data structures in the `collections` module.
#
# #### **1.1 `Counter`**
#
# - **Purpose**: Counts the frequency of elements in an iterable.
# - **Use Case**: Counting occurrences of items in a list, string, or any iterable.
# - **Example**:
#
#   ```python
#   from collections import Counter
#
#   data = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
#   counter = Counter(data)
#   print(counter)  # Output: Counter({'apple': 3, 'banana': 2, 'orange': 1})
#   print(counter['apple'])  # Output: 3
#   ```
#
# #### **1.2 `defaultdict`**
#
# - **Purpose**: A dictionary subclass that provides default values for missing keys.
# - **Use Case**: Avoiding `KeyError` when accessing keys that don’t exist.
# - **Example**:
#
#   ```python
#   from collections import defaultdict
#
#   dd = defaultdict(int)  # Default value is 0
#   dd['apple'] += 1
#   print(dd['apple'])  # Output: 1
#   print(dd['banana'])  # Output: 0 (default value)
#   ```
#
# #### **1.3 `deque`**
#
# - **Purpose**: A double-ended queue for fast appends and pops from both ends.
# - **Use Case**: Implementing queues, stacks, or sliding window algorithms.
# - **Example**:
#
#   ```python
#   from collections import deque
#
#   dq = deque([1, 2, 3])
#   dq.append(4)  # Add to the right
#   dq.appendleft(0)  # Add to the left
#   print(dq)  # Output: deque([0, 1, 2, 3, 4])
#   dq.pop()  # Remove from the right
#   dq.popleft()  # Remove from the left
#   print(dq)  # Output: deque([1, 2, 3])
#   ```
#
# #### **1.4 `namedtuple`**
#
# - **Purpose**: Creates a lightweight object type with named fields.
# - **Use Case**: When you need a simple immutable data structure with named attributes.
# - **Example**:
#
#   ```python
#   from collections import namedtuple
#
#   Point = namedtuple('Point', ['x', 'y'])
#   p = Point(10, 20)
#   print(p.x, p.y)  # Output: 10 20
#   print(p[0], p[1])  # Output: 10 20 (also accessible by index)
#   ```
#
# ---
#
# ### **2. Advanced Collections**
#
# These are less commonly used but very powerful in specific scenarios.
#
# #### **2.1 `ChainMap`**
#
# - **Purpose**: Combines multiple dictionaries into a single mapping.
# - **Use Case**: Searching through multiple dictionaries as if they were one.
# - **Example**:
#
#   ```python
#   from collections import ChainMap
#
#   dict1 = {'a': 1, 'b': 2}
#   dict2 = {'b': 3, 'c': 4}
#   chain = ChainMap(dict1, dict2)
#   print(chain['a'])  # Output: 1 (from dict1)
#   print(chain['b'])  # Output: 2 (from dict1, first match)
#   print(chain['c'])  # Output: 4 (from dict2)
#   ```
#
# #### **2.2 `OrderedDict`**
#
# - **Purpose**: A dictionary subclass that remembers the order of insertion.
# - **Use Case**: When the order of keys matters (e.g., LRU cache).
# - **Example**:
#
#   ```python
#   from collections import OrderedDict
#
#   od = OrderedDict()
#   od['a'] = 1
#   od['b'] = 2
#   od['c'] = 3
#   print(od)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3)])
#   ```
#
# #### **2.3 `UserDict`, `UserList`, `UserString`**
#
# - **Purpose**: Wrapper classes for creating custom dictionary, list, and string types.
# - **Use Case**: When you need to extend or modify the behavior of built-in types.
# - **Example**:
#
#   ```python
#   from collections import UserDict
#
#   class MyDict(UserDict):
#       def __missing__(self, key):
#           return f"Key '{key}' not found!"
#
#   my_dict = MyDict({'a': 1, 'b': 2})
#   print(my_dict['a'])  # Output: 1
#   print(my_dict['c'])  # Output: Key 'c' not found!
#   ```
#
# ---
#
# ### **3. Practical Use Cases**
#
# #### **3.1 Counting Word Frequencies**
#
# ```python
# from collections import Counter
#
# text = "hello world hello python world"
# words = text.split()
# word_count = Counter(words)
# print(word_count.most_common(2))  # Output: [('hello', 2), ('world', 2)]
# ```
#
# #### **3.2 Implementing a Queue**
#
# ```python
# from collections import deque
#
# queue = deque()
# queue.append(1)
# queue.append(2)
# queue.append(3)
# print(queue.popleft())  # Output: 1 (FIFO)
# ```
#
# #### **3.3 Grouping Data with `defaultdict`**
#
# ```python
# from collections import defaultdict
#
# data = [('apple', 'fruit'), ('carrot', 'vegetable'), ('banana', 'fruit')]
# grouped = defaultdict(list)
#
# for item, category in data:
#     grouped[category].append(item)
#
# print(grouped)  # Output: {'fruit': ['apple', 'banana'], 'vegetable': ['carrot']}
# ```
#
# #### **3.4 Creating Immutable Data Structures**
#
# ```python
# from collections import namedtuple
#
# Person = namedtuple('Person', ['name', 'age'])
# person = Person(name="Alice", age=30)
# print(person.name, person.age)  # Output: Alice 30
# ```
#
# ---
#
# ### **4. Advanced Techniques**
#
# #### **4.1 Combining `Counter` with Arithmetic Operations**
#
# ```python
# from collections import Counter
#
# c1 = Counter(a=3, b=1)
# c2 = Counter(a=1, b=2)
# print(c1 + c2)  # Output: Counter({'a': 4, 'b': 3})
# print(c1 - c2)  # Output: Counter({'a': 2})
# ```
#
# #### **4.2 Using `deque` for Sliding Window Problems**
#
# ```python
# from collections import deque
#
# def sliding_window_max(nums, k):
#     dq = deque()
#     result = []
#     for i, num in enumerate(nums):
#         while dq and nums[dq[-1]] < num:
#             dq.pop()
#         dq.append(i)
#         if dq[0] == i - k:
#             dq.popleft()
#         if i >= k - 1:
#             result.append(nums[dq[0]])
#     return result
#
# nums = [1, 3, -1, -3, 5, 3, 6, 7]
# print(sliding_window_max(nums, 3))  # Output: [3, 3, 5, 5, 6, 7]
# ```
#
# #### **4.3 Customizing `defaultdict` Behavior**
#
# ```python
# from collections import defaultdict
#
# def default_value():
#     return "Unknown"
#
# dd = defaultdict(default_value)
# print(dd['key'])  # Output: Unknown
# ```
#
# ---
#
# ### **5. Summary**
#
# The `collections` module provides a rich set of tools for handling specialized data structures. Here’s a quick recap:
#
# - **`Counter`**: Counts elements in an iterable.
# - **`defaultdict`**: Provides default values for missing keys.
# - **`deque`**: Efficient double-ended queue.
# - **`namedtuple`**: Lightweight immutable objects with named fields.
# - **`ChainMap`**: Combines multiple dictionaries.
# - **`OrderedDict`**: Preserves insertion order.
# - **`UserDict`, `UserList`, `UserString`**: Customizable wrappers for built-in types.
#
# By mastering these tools, you can write more efficient and readable Python code.
#
# The `collections` module in Python is a powerful module that provides specialized container data types as alternatives to the built-in containers like `list`, `dict`, `set`, and `tuple`. These specialized data types are designed to be more efficient and convenient for specific use cases. Below is a comprehensive guide to the `collections` module, covering everything from basic to advanced usage.
#
# ### 1. **`namedtuple`**
#
# A `namedtuple` is a factory function for creating tuple subclasses with named fields. It allows you to create immutable objects with named attributes, making your code more readable.
#
# #### Basic Usage:
#
# ```python
# from collections import namedtuple
#
# # Define a namedtuple
# Point = namedtuple('Point', ['x', 'y'])
#
# # Create an instance
# p = Point(10, 20)
#
# # Access fields
# print(p.x)  # Output: 10
# print(p.y)  # Output: 20
# ```
#
# #### Advanced Usage:
#
# - **Default Values:** You can provide default values using the `defaults` argument.
# - **Methods:** `_replace()`, `_asdict()`, `_make()`, etc.
#
# ```python
# Point = namedtuple('Point', ['x', 'y'], defaults=[0, 0])
# p = Point()
# print(p)  # Output: Point(x=0, y=0)
# ```
#
# ### 2. **`deque`**
#
# A `deque` (double-ended queue) is a list-like container with fast appends and pops on both ends. It is thread-safe and can be used as a stack or queue.
#
# #### Basic Usage:
#
# ```python
# from collections import deque
#
# # Create a deque
# d = deque([1, 2, 3])
#
# # Append to the right
# d.append(4)
#
# # Append to the left
# d.appendleft(0)
#
# # Pop from the right
# d.pop()
#
# # Pop from the left
# d.popleft()
#
# print(d)  # Output: deque([0, 1, 2, 3])
# ```
#
# #### Advanced Usage:
#
# - **Maxlen:** You can set a maximum length for the deque.
# - **Rotate:** Rotate the deque `n` steps to the right (negative `n` rotates left).
#
# ```python
# d = deque(maxlen=3)
# d.extend([1, 2, 3])
# d.append(4)
# print(d)  # Output: deque([2, 3, 4], maxlen=3)
#
# d.rotate(1)
# print(d)  # Output: deque([4, 2, 3], maxlen=3)
# ```
#
# ### 3. **`ChainMap`**
#
# A `ChainMap` groups multiple dictionaries or mappings together to create a single, updateable view. It is useful for managing multiple contexts or configurations.
#
# #### Basic Usage:
#
# ```python
# from collections import ChainMap
#
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}
#
# # Create a ChainMap
# chain = ChainMap(dict1, dict2)
#
# # Access values
# print(chain['a'])  # Output: 1
# print(chain['b'])  # Output: 2 (from dict1)
# print(chain['c'])  # Output: 4
# ```
#
# #### Advanced Usage:
#
# - **New Child:** Add a new dictionary to the beginning of the chain.
# - **Parents:** Access the parent mappings.
#
# ```python
# dict3 = {'d': 5}
# chain = chain.new_child(dict3)
# print(chain['d'])  # Output: 5
#
# parent_chain = chain.parents
# print(parent_chain['b'])  # Output: 2
# ```
#
# ### 4. **`Counter`**
#
# A `Counter` is a dictionary subclass for counting hashable objects. It is useful for counting occurrences of elements in a collection.
#
# #### Basic Usage:
#
# ```python
# from collections import Counter
#
# # Create a Counter
# c = Counter(['apple', 'banana', 'apple', 'orange', 'banana', 'apple'])
#
# # Access counts
# print(c['apple'])  # Output: 3
# print(c['banana'])  # Output: 2
#
# # Most common elements
# print(c.most_common(2))  # Output: [('apple', 3), ('banana', 2)]
# ```
#
# #### Advanced Usage:
#
# - **Arithmetic Operations:** You can add, subtract, intersect, and union counters.
# - **Elements:** Get an iterator over elements repeating each as many times as its count.
#
# ```python
# c1 = Counter(a=3, b=1)
# c2 = Counter(a=1, b=2)
#
# # Addition
# print(c1 + c2)  # Output: Counter({'a': 4, 'b': 3})
#
# # Subtraction
# print(c1 - c2)  # Output: Counter({'a': 2})
#
# # Intersection
# print(c1 & c2)  # Output: Counter({'a': 1, 'b': 1})
#
# # Union
# print(c1 | c2)  # Output: Counter({'a': 3, 'b': 2})
# ```
#
# ### 5. **`OrderedDict`**
#
# An `OrderedDict` is a dictionary subclass that remembers the order in which items were added. It is useful when the order of insertion matters.
#
# #### Basic Usage:
#
# ```python
# from collections import OrderedDict
#
# # Create an OrderedDict
# od = OrderedDict()
# od['a'] = 1
# od['b'] = 2
# od['c'] = 3
#
# # Iterate in order
# for key, value in od.items():
#     print(key, value)
# # Output:
# # a 1
# # b 2
# # c 3
# ```
#
# #### Advanced Usage:
#
# - **Move to End:** Move an existing key to either end of the dictionary.
# - **Pop Item:** Remove and return a (key, value) pair.
#
# ```python
# od.move_to_end('a')
# print(od)  # Output: OrderedDict([('b', 2), ('c', 3), ('a', 1)])
#
# od.popitem(last=False)
# print(od)  # Output: OrderedDict([('c', 3), ('a', 1)])
# ```
#
# ### 6. **`defaultdict`**
#
# A `defaultdict` is a dictionary subclass that calls a factory function to supply missing values. It is useful when you want to handle missing keys without raising a `KeyError`.
#
# #### Basic Usage:
#
# ```python
# from collections import defaultdict
#
# # Create a defaultdict with a default value of 0
# dd = defaultdict(int)
#
# # Access a missing key
# dd['a'] += 1
# print(dd['a'])  # Output: 1
# ```
#
# #### Advanced Usage:
#
# - **Custom Factory:** You can use any callable as the factory function.
# - **Nested Defaultdicts:** Useful for creating nested dictionaries.
#
# ```python
# dd = defaultdict(lambda: defaultdict(int))
# dd['a']['b'] += 1
# print(dd['a']['b'])  # Output: 1
# ```
#
# ### 7. **`UserDict`, `UserList`, `UserString`**
#
# These are wrapper classes around dictionary, list, and string objects, respectively. They are useful when you want to create custom container types by subclassing.
#
# #### Basic Usage:
#
# ```python
# from collections import UserDict, UserList, UserString
#
# # UserDict
# class MyDict(UserDict):
#     def __missing__(self, key):
#         return 'default'
#
# md = MyDict({'a': 1})
# print(md['b'])  # Output: default
#
# # UserList
# class MyList(UserList):
#     def append_if_not_exists(self, item):
#         if item not in self.data:
#             self.data.append(item)
#
# ml = MyList([1, 2, 3])
# ml.append_if_not_exists(2)
# print(ml)  # Output: [1, 2, 3]
#
# # UserString
# class MyString(UserString):
#     def reverse(self):
#         return self.data[::-1]
#
# ms = MyString('hello')
# print(ms.reverse())  # Output: olleh
# ```
#
# ### 8. **`Counter` with `most_common`**
#
# The `most_common` method of `Counter` returns a list of the `n` most common elements and their counts.
#
# #### Advanced Usage:
#
# ```python
# from collections import Counter
#
# c = Counter('abracadabra')
# print(c.most_common(3))  # Output: [('a', 5), ('b', 2), ('r', 2)]
# ```
#
# ### 9. **`ChainMap` with `new_child` and `parents`**
#
# The `new_child` method adds a new dictionary to the beginning of the chain, while `parents` returns a new `ChainMap` containing all the maps except the first one.
#
# #### Advanced Usage:
#
# ```python
# from collections import ChainMap
#
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}
# dict3 = {'d': 5}
#
# chain = ChainMap(dict1, dict2)
# chain = chain.new_child(dict3)
#
# print(chain['d'])  # Output: 5
#
# parent_chain = chain.parents
# print(parent_chain['b'])  # Output: 2
# ```
#
# ### 10. **`deque` with `rotate`**
#
# The `rotate` method rotates the deque `n` steps to the right (negative `n` rotates left).
#
# #### Advanced Usage:
#
# ```python
# from collections import deque
#
# d = deque([1, 2, 3, 4, 5])
# d.rotate(2)
# print(d)  # Output: deque([4, 5, 1, 2, 3])
#
# d.rotate(-2)
# print(d)  # Output: deque([1, 2, 3, 4, 5])
# ```
#
# ### 11. **`namedtuple` with `_replace`**
#
# The `_replace` method returns a new instance of the namedtuple with specified fields replaced.
#
# #### Advanced Usage:
#
# ```python
# from collections import namedtuple
#
# Point = namedtuple('Point', ['x', 'y'])
# p = Point(10, 20)
# p = p._replace(x=15)
# print(p)  # Output: Point(x=15, y=20)
# ```
#
# ### 12. **`defaultdict` with Custom Factory**
#
# You can use any callable as the factory function for `defaultdict`.
#
# #### Advanced Usage:
#
# ```python
# from collections import defaultdict
#
# def default_factory():
#     return 'default value'
#
# dd = defaultdict(default_factory)
# print(dd['a'])  # Output: default value
# ```
#
# ### 13. **`OrderedDict` with `move_to_end`**
#
# The `move_to_end` method moves an existing key to either end of the dictionary.
#
# #### Advanced Usage:
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# od.move_to_end('a')
# print(od)  # Output: OrderedDict([('b', 2), ('c', 3), ('a', 1)])
# ```
#
# ### 14. **`Counter` with Arithmetic Operations**
#
# You can perform arithmetic operations like addition, subtraction, intersection, and union on `Counter` objects.
#
# #### Advanced Usage:
#
# ```python
# from collections import Counter
#
# c1 = Counter(a=3, b=1)
# c2 = Counter(a=1, b=2)
#
# # Addition
# print(c1 + c2)  # Output: Counter({'a': 4, 'b': 3})
#
# # Subtraction
# print(c1 - c2)  # Output: Counter({'a': 2})
#
# # Intersection
# print(c1 & c2)  # Output: Counter({'a': 1, 'b': 1})
#
# # Union
# print(c1 | c2)  # Output: Counter({'a': 3, 'b': 2})
# ```
#
# ### 15. **`ChainMap` with `maps` Attribute**
#
# The `maps` attribute of `ChainMap` returns a list of the underlying mappings.
#
# #### Advanced Usage:
#
# ```python
# from collections import ChainMap
#
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}
#
# chain = ChainMap(dict1, dict2)
# print(chain.maps)  # Output: [{'a': 1, 'b': 2}, {'b': 3, 'c': 4}]
# ```
#
# ### 16. **`deque` with `maxlen`**
#
# The `maxlen` attribute of `deque` sets the maximum length of the deque. When the deque is full, adding new items will remove items from the opposite end.
#
# #### Advanced Usage:
#
# ```python
# from collections import deque
#
# d = deque(maxlen=3)
# d.extend([1, 2, 3])
# d.append(4)
# print(d)  # Output: deque([2, 3, 4], maxlen=3)
# ```
#
# ### 17. **`namedtuple` with `_asdict`**
#
# The `_asdict` method returns a new `OrderedDict` which maps field names to their corresponding values.
#
# #### Advanced Usage:
#
# ```python
# from collections import namedtuple
#
# Point = namedtuple('Point', ['x', 'y'])
# p = Point(10, 20)
# print(p._asdict())  # Output: OrderedDict([('x', 10), ('y', 20)])
# ```
#
# ### 18. **`Counter` with `elements`**
#
# The `elements` method returns an iterator over elements repeating each as many times as its count.
#
# #### Advanced Usage:
#
# ```python
# from collections import Counter
#
# c = Counter(a=3, b=1)
# print(list(c.elements()))  # Output: ['a', 'a', 'a', 'b']
# ```
#
# ### 19. **`OrderedDict` with `popitem`**
#
# The `popitem` method removes and returns a (key, value) pair from the dictionary. The `last` argument determines whether to remove from the end (default) or the beginning.
#
# #### Advanced Usage:
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# od.popitem(last=False)
# print(od)  # Output: OrderedDict([('b', 2), ('c', 3)])
# ```
#
# ### 20. **`defaultdict` with Nested Defaultdicts**
#
# You can create nested `defaultdict` structures for more complex data organization.
#
# #### Advanced Usage:
#
# ```python
# from collections import defaultdict
#
# dd = defaultdict(lambda: defaultdict(int))
# dd['a']['b'] += 1
# print(dd['a']['b'])  # Output: 1
# ```
#
# ### Conclusion
#
# The `collections` module in Python provides a rich set of specialized container data types that can greatly simplify and optimize your code. By understanding and leveraging these tools, you can write more efficient, readable, and maintainable Python programs. Whether you're counting elements, managing ordered dictionaries, or creating custom container types, the `collections` module has something to offer.
#
# The `collections` module in Python is a powerful module that provides specialized container data types as alternatives to the built-in containers like `list`, `tuple`, `dict`, and `set`. These specialized data types are designed to be more efficient and convenient for specific use cases. Below is a comprehensive guide to the `collections` module, covering everything from basic to advanced usage.
#
# ---
#
# ### **1. Overview of `collections` Module**
#
# The `collections` module includes the following data structures:
#
# - `namedtuple`: Creates tuple-like objects with named fields.
# - `deque`: A double-ended queue for fast appends and pops.
# - `ChainMap`: Combines multiple dictionaries into a single view.
# - `Counter`: Counts hashable objects.
# - `OrderedDict`: A dictionary that maintains insertion order.
# - `defaultdict`: A dictionary with default values for missing keys.
# - `UserDict`, `UserList`, `UserString`: Wrapper classes for creating custom dictionary, list, and string-like objects.
#
# ---
#
# ### **2. `namedtuple`**
#
# A `namedtuple` is a subclass of a tuple with named fields. It is immutable and memory-efficient.
#
# #### **Basic Usage**
#
# ```python
# from collections import namedtuple
#
# # Define a namedtuple
# Person = namedtuple('Person', ['name', 'age', 'gender'])
#
# # Create an instance
# p = Person(name='Alice', age=30, gender='Female')
#
# # Access fields
# print(p.name)   # Output: Alice
# print(p.age)    # Output: 30
# print(p[0])     # Output: Alice (index-based access)
# ```
#
# #### **Advanced Usage**
#
# - Use `_asdict()` to convert to a dictionary.
# - Use `_replace()` to create a new instance with updated values.
#
# ```python
# # Convert to dictionary
# print(p._asdict())  # Output: {'name': 'Alice', 'age': 30, 'gender': 'Female'}
#
# # Replace a value
# p_new = p._replace(age=31)
# print(p_new)  # Output: Person(name='Alice', age=31, gender='Female')
# ```
#
# ---
#
# ### **3. `deque`**
#
# A `deque` (double-ended queue) is optimized for fast appends and pops from both ends.
#
# #### **Basic Usage**
#
# ```python
# from collections import deque
#
# # Create a deque
# d = deque([1, 2, 3])
#
# # Append to the right
# d.append(4)  # deque([1, 2, 3, 4])
#
# # Append to the left
# d.appendleft(0)  # deque([0, 1, 2, 3, 4])
#
# # Pop from the right
# d.pop()  # Returns 4, deque([0, 1, 2, 3])
#
# # Pop from the left
# d.popleft()  # Returns 0, deque([1, 2, 3])
# ```
#
# #### **Advanced Usage**
#
# - Use `maxlen` to create a bounded deque.
# - Use `rotate()` to shift elements.
#
# ```python
# # Bounded deque
# d = deque(maxlen=3)
# d.extend([1, 2, 3])  # deque([1, 2, 3])
# d.append(4)  # deque([2, 3, 4]) (oldest element is removed)
#
# # Rotate elements
# d.rotate(1)  # deque([4, 2, 3])
# d.rotate(-1)  # deque([2, 3, 4])
# ```
#
# ---
#
# ### **4. `ChainMap`**
#
# A `ChainMap` groups multiple dictionaries into a single view.
#
# #### **Basic Usage**
#
# ```python
# from collections import ChainMap
#
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}
#
# # Create a ChainMap
# cm = ChainMap(dict1, dict2)
#
# # Access values
# print(cm['a'])  # Output: 1 (from dict1)
# print(cm['b'])  # Output: 2 (from dict1, first match)
# print(cm['c'])  # Output: 4 (from dict2)
# ```
#
# #### **Advanced Usage**
#
# - Use `new_child()` to add a new dictionary to the beginning.
# - Use `parents` to skip the first dictionary.
#
# ```python
# # Add a new dictionary
# dict3 = {'d': 5}
# cm = cm.new_child(dict3)
#
# # Access parents
# print(cm.parents)  # ChainMap({'a': 1, 'b': 2}, {'b': 3, 'c': 4})
# ```
#
# ---
#
# ### **5. `Counter`**
#
# A `Counter` is a dictionary subclass for counting hashable objects.
#
# #### **Basic Usage**
#
# ```python
# from collections import Counter
#
# # Create a Counter
# c = Counter(['apple', 'banana', 'apple', 'orange', 'banana', 'apple'])
#
# # Count elements
# print(c)  # Output: Counter({'apple': 3, 'banana': 2, 'orange': 1})
#
# # Access counts
# print(c['apple'])  # Output: 3
# ```
#
# #### **Advanced Usage**
#
# - Use `most_common()` to get the most frequent elements.
# - Use arithmetic operations like `+`, `-`, `&`, `|`.
#
# ```python
# # Most common elements
# print(c.most_common(2))  # Output: [('apple', 3), ('banana', 2)]
#
# # Arithmetic operations
# c1 = Counter(a=3, b=1)
# c2 = Counter(a=1, b=2)
# print(c1 + c2)  # Output: Counter({'a': 4, 'b': 3})
# print(c1 - c2)  # Output: Counter({'a': 2})
# ```
#
# ---
#
# ### **6. `OrderedDict`**
#
# An `OrderedDict` maintains the insertion order of keys.
#
# #### **Basic Usage**
#
# ```python
# from collections import OrderedDict
#
# # Create an OrderedDict
# od = OrderedDict()
# od['a'] = 1
# od['b'] = 2
# od['c'] = 3
#
# # Iterate in insertion order
# for key, value in od.items():
#     print(key, value)  # Output: a 1, b 2, c 3
# ```
#
# #### **Advanced Usage**
#
# - Use `move_to_end()` to move a key to the beginning or end.
# - Use `popitem()` to remove and return the last or first item.
#
# ```python
# # Move a key to the end
# od.move_to_end('a')  # OrderedDict([('b', 2), ('c', 3), ('a', 1)])
#
# # Pop the last item
# od.popitem()  # Returns ('a', 1)
# ```
#
# ---
#
# ### **7. `defaultdict`**
#
# A `defaultdict` provides default values for missing keys.
#
# #### **Basic Usage**
#
# ```python
# from collections import defaultdict
#
# # Create a defaultdict with default value 0
# dd = defaultdict(int)
#
# # Access missing key
# print(dd['a'])  # Output: 0 (default value)
# ```
#
# #### **Advanced Usage**
#
# - Use a lambda function to define custom default values.
#
# ```python
# # Custom default value
# dd = defaultdict(lambda: 'unknown')
# print(dd['a'])  # Output: unknown
# ```
#
# ---
#
# ### **8. `UserDict`, `UserList`, `UserString`**
#
# These are wrapper classes for creating custom dictionary, list, and string-like objects.
#
# #### **Basic Usage**
#
# ```python
# from collections import UserDict, UserList, UserString
#
# # Custom dictionary
# class MyDict(UserDict):
#     def __missing__(self, key):
#         return 'default'
#
# md = MyDict({'a': 1})
# print(md['b'])  # Output: default
# ```
#
# ---
#
# ### **9. Practical Use Cases**
#
# - **`Counter`**: Counting word frequencies in text.
# - **`defaultdict`**: Grouping items by a key.
# - **`deque`**: Implementing a queue or stack.
# - **`namedtuple`**: Representing records or data points.
# - **`ChainMap`**: Managing configuration settings with fallbacks.
#
# ---
#
# ### **10. Summary**
#
# The `collections` module provides specialized data structures that are more efficient and convenient than built-in containers for specific tasks. By mastering these tools, you can write cleaner, faster, and more Pythonic code.

# %% [markdown]
# The `collections` module in Python is a built-in module that provides specialized container data types as alternatives to the general-purpose built-in containers like `list`, `dict`, `set`, and `tuple`. These specialized data structures are designed to handle specific use cases more efficiently and conveniently.
#
# Below is a comprehensive guide to the `collections` module, covering everything from basic to advanced concepts:
#
# ---
#
# ### **1. Overview of Collections Module**
#
# The `collections` module includes the following data structures:
#
# - `namedtuple`
# - `deque`
# - `ChainMap`
# - `Counter`
# - `OrderedDict`
# - `defaultdict`
# - `UserDict`
# - `UserList`
# - `UserString`
#
# Let’s explore each of these in detail.
#
# ---
#
# ### **2. `namedtuple`**
#
# A `namedtuple` is a subclass of a tuple with named fields. It allows you to access elements by name instead of just index.
#
# #### **Syntax:**
#
# ```python
# from collections import namedtuple
# Point = namedtuple('Point', ['x', 'y'])
# ```
#
# #### **Example:**
#
# ```python
# p = Point(10, 20)
# print(p.x)  # Output: 10
# print(p.y)  # Output: 20
# ```
#
# #### **Use Cases:**
#
# - When you need immutable objects with named fields.
# - As a lightweight alternative to classes.
#
# ---
#
# ### **3. `deque` (Double-Ended Queue)**
#
# A `deque` is a list-like container with fast appends and pops from both ends.
#
# #### **Syntax:**
#
# ```python
# from collections import deque
# d = deque([1, 2, 3])
# ```
#
# #### **Example:**
#
# ```python
# d.append(4)       # Add to the right
# d.appendleft(0)   # Add to the left
# print(d)          # Output: deque([0, 1, 2, 3, 4])
#
# d.pop()           # Remove from the right
# d.popleft()       # Remove from the left
# print(d)          # Output: deque([1, 2, 3])
# ```
#
# #### **Use Cases:**
#
# - Implementing queues and stacks.
# - Sliding window algorithms.
#
# ---
#
# ### **4. `ChainMap`**
#
# A `ChainMap` groups multiple dictionaries into a single mapping. Lookups search the underlying mappings successively until a key is found.
#
# #### **Syntax:**
#
# ```python
# from collections import ChainMap
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'c': 3, 'b': 4}
# chain = ChainMap(dict1, dict2)
# ```
#
# #### **Example:**
#
# ```python
# print(chain['a'])  # Output: 1 (from dict1)
# print(chain['b'])  # Output: 2 (from dict1, first match)
# print(chain['c'])  # Output: 3 (from dict2)
# ```
#
# #### **Use Cases:**
#
# - Combining multiple configurations or settings.
# - Managing nested scopes.
#
# ---
#
# ### **5. `Counter`**
#
# A `Counter` is a dictionary subclass for counting hashable objects.
#
# #### **Syntax:**
#
# ```python
# from collections import Counter
# c = Counter(['a', 'b', 'a', 'c', 'b', 'a'])
# ```
#
# #### **Example:**
#
# ```python
# print(c)  # Output: Counter({'a': 3, 'b': 2, 'c': 1})
#
# # Most common elements
# print(c.most_common(2))  # Output: [('a', 3), ('b', 2)]
# ```
#
# #### **Use Cases:**
#
# - Counting frequencies of elements in a collection.
# - Finding the most common elements.
#
# ---
#
# ### **6. `OrderedDict`**
#
# An `OrderedDict` is a dictionary subclass that remembers the order in which items were inserted.
#
# #### **Syntax:**
#
# ```python
# from collections import OrderedDict
# od = OrderedDict()
# od['a'] = 1
# od['b'] = 2
# ```
#
# #### **Example:**
#
# ```python
# print(od)  # Output: OrderedDict([('a', 1), ('b', 2)])
# ```
#
# #### **Use Cases:**
#
# - When insertion order matters.
# - Implementing LRU (Least Recently Used) caches.
#
# ---
#
# ### **7. `defaultdict`**
#
# A `defaultdict` is a dictionary subclass that provides a default value for missing keys.
#
# #### **Syntax:**
#
# ```python
# from collections import defaultdict
# dd = defaultdict(int)  # Default value for missing keys is 0
# ```
#
# #### **Example:**
#
# ```python
# dd['a'] = 1
# print(dd['a'])  # Output: 1
# print(dd['b'])  # Output: 0 (default value)
# ```
#
# #### **Use Cases:**
#
# - Grouping or aggregating data.
# - Handling missing keys gracefully.
#
# ---
#
# ### **8. `UserDict`, `UserList`, `UserString`**
#
# These are wrapper classes for creating custom dictionary, list, and string-like objects.
#
# #### **Syntax:**
#
# ```python
# from collections import UserDict, UserList, UserString
# ```
#
# #### **Example:**
#
# ```python
# class MyDict(UserDict):
#     def __missing__(self, key):
#         return f"Key '{key}' not found"
#
# md = MyDict({'a': 1})
# print(md['b'])  # Output: Key 'b' not found
# ```
#
# #### **Use Cases:**
#
# - Extending or customizing built-in types.
#
# ---
#
# ### **9. Advanced Topics**
#
# #### **a. Combining `Counter` with Other Data Structures**
#
# You can combine `Counter` with `deque` or `defaultdict` for advanced use cases.
#
# #### **b. Customizing `OrderedDict`**
#
# You can implement custom behaviors like LRU caching using `OrderedDict`.
#
# #### **c. Nested `ChainMap`**
#
# You can nest `ChainMap` objects to manage deeply nested configurations.
#
# ---
#
# ### **10. Practical Examples**
#
# #### **Example 1: Word Frequency Counter**
#
# ```python
# from collections import Counter
# text = "hello world hello"
# word_count = Counter(text.split())
# print(word_count)  # Output: Counter({'hello': 2, 'world': 1})
# ```
#
# #### **Example 2: Implementing a Queue**
#
# ```python
# from collections import deque
# queue = deque()
# queue.append(1)
# queue.append(2)
# queue.append(3)
# print(queue.popleft())  # Output: 1
# ```
#
# #### **Example 3: Grouping Data**
#
# ```python
# from collections import defaultdict
# data = [('apple', 1), ('banana', 2), ('apple', 3)]
# grouped = defaultdict(list)
# for key, value in data:
#     grouped[key].append(value)
# print(grouped)  # Output: defaultdict(<class 'list'>, {'apple': [1, 3], 'banana': [2]})
# ```
#
# ---
#
# ### **11. Performance Considerations**
#
# - `deque`: O(1) for append and pop operations at both ends.
# - `Counter`: Efficient for counting elements in large datasets.
# - `defaultdict`: Avoids key errors and simplifies code.
#
# ---
#
# ### **12. When to Use Which?**
#
# - Use `namedtuple` for lightweight, immutable objects.
# - Use `deque` for queues or stacks.
# - Use `Counter` for counting elements.
# - Use `OrderedDict` when insertion order matters.
# - Use `defaultdict` for handling missing keys.
# - Use `ChainMap` for combining multiple dictionaries.
#
# ---
#
# This covers everything from the basics to advanced usage of the `collections` module in Python. Let me know if you need further clarification or examples!

# %% [markdown]
# The **`collections` module** in Python provides specialized container datatypes that are alternatives to Python's built-in containers like `list`, `dict`, `set`, and `tuple`. These specialized containers are designed to handle specific use cases more efficiently and conveniently. One of the most commonly used classes in the `collections` module is **`Counter`**, which is used for counting hashable objects.
#
# Below is a comprehensive guide to the `Counter` class and other important classes in the `collections` module, covering everything from basic usage to advanced concepts.
#
# ---
#
# ## **1. Basic Concepts**
#
# ### **What is the `collections` Module?**
#
# - The `collections` module provides specialized container datatypes.
# - These containers are designed to be more efficient and convenient for specific use cases.
#
# ### **Why Use the `collections` Module?**
#
# - **Efficiency**: Optimized for specific tasks.
# - **Convenience**: Provides additional functionality not available in built-in containers.
# - **Readability**: Makes code more expressive and easier to understand.
#
# ---
#
# ## **2. `Counter` Class**
#
# ### **What is `Counter`?**
#
# - `Counter` is a subclass of `dict` designed for counting hashable objects.
# - It stores elements as dictionary keys and their counts as dictionary values.
#
# ### **Basic Syntax**
#
# ```python
# from collections import Counter
#
# counter = Counter(iterable)
# ```
#
# ---
#
# ### **Example: Basic Usage**
#
# ```python
# from collections import Counter
#
# # Count elements in a list
# data = ["apple", "banana", "apple", "orange", "banana", "apple"]
# counter = Counter(data)
#
# print(counter)  # Output: Counter({'apple': 3, 'banana': 2, 'orange': 1})
# ```
#
# ---
#
# ### **Common Methods of `Counter`**
#
# #### **1. `elements()`**
#
# - Returns an iterator over elements, repeating each as many times as its count.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter(a=3, b=2, c=1)
# print(list(counter.elements()))  # Output: ['a', 'a', 'a', 'b', 'b', 'c']
# ```
#
# ---
#
# #### **2. `most_common(n)`**
#
# - Returns a list of the `n` most common elements and their counts.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter(a=3, b=2, c=1)
# print(counter.most_common(2))  # Output: [('a', 3), ('b', 2)]
# ```
#
# ---
#
# #### **3. `update(iterable)`**
#
# - Updates the counter with elements from an iterable or another counter.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter(a=3, b=2)
# counter.update(["a", "b", "c"])
#
# print(counter)  # Output: Counter({'a': 4, 'b': 3, 'c': 1})
# ```
#
# ---
#
# #### **4. `subtract(iterable)`**
#
# - Subtracts elements from an iterable or another counter.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter(a=3, b=2)
# counter.subtract(["a", "b"])
#
# print(counter)  # Output: Counter({'a': 2, 'b': 1})
# ```
#
# ---
#
# #### **5. Arithmetic Operations**
#
# - `Counter` supports addition (`+`), subtraction (`-`), intersection (`&`), and union (`|`).
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter1 = Counter(a=3, b=2)
# counter2 = Counter(a=1, b=2, c=1)
#
# # Addition
# print(counter1 + counter2)  # Output: Counter({'a': 4, 'b': 4, 'c': 1})
#
# # Subtraction
# print(counter1 - counter2)  # Output: Counter({'a': 2})
#
# # Intersection
# print(counter1 & counter2)  # Output: Counter({'a': 1, 'b': 2})
#
# # Union
# print(counter1 | counter2)  # Output: Counter({'a': 3, 'b': 2, 'c': 1})
# ```
#
# ---
#
# ## **3. Other Classes in the `collections` Module**
#
# ### **1. `defaultdict`**
#
# - A subclass of `dict` that provides a default value for missing keys.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Default value for missing keys is an empty list
# dd = defaultdict(list)
# dd["fruits"].append("apple")
# dd["fruits"].append("banana")
#
# print(dd)  # Output: defaultdict(<class 'list'>, {'fruits': ['apple', 'banana']})
# ```
#
# ---
#
# ### **2. `deque`**
#
# - A double-ended queue optimized for fast appends and pops from both ends.
#
# #### **Example**
#
# ```python
# from collections import deque
#
# d = deque([1, 2, 3])
# d.append(4)        # Add to the right
# d.appendleft(0)    # Add to the left
# d.pop()            # Remove from the right
# d.popleft()        # Remove from the left
#
# print(d)  # Output: deque([0, 1, 2, 3])
# ```
#
# ---
#
# ### **3. `namedtuple`**
#
# - A factory function for creating tuple subclasses with named fields.
#
# #### **Example**
#
# ```python
# from collections import namedtuple
#
# Point = namedtuple("Point", ["x", "y"])
# p = Point(10, 20)
#
# print(p.x, p.y)  # Output: 10 20
# ```
#
# ---
#
# ### **4. `ChainMap`**
#
# - A class for combining multiple dictionaries or mappings into a single view.
#
# #### **Example**
#
# ```python
# from collections import ChainMap
#
# dict1 = {"a": 1, "b": 2}
# dict2 = {"b": 3, "c": 4}
#
# chain = ChainMap(dict1, dict2)
# print(chain["a"])  # Output: 1 (from dict1)
# print(chain["b"])  # Output: 2 (from dict1, first match)
# print(chain["c"])  # Output: 4 (from dict2)
# ```
#
# ---
#
# ### **5. `OrderedDict`**
#
# - A subclass of `dict` that maintains the order of keys.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict()
# od["a"] = 1
# od["b"] = 2
# od["c"] = 3
#
# print(od)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# ```
#
# ---
#
# ## **4. Advanced Usage**
#
# ### **1. Combining `Counter` with Other Classes**
#
# - `Counter` can be combined with other classes like `defaultdict` or `deque` for advanced use cases.
#
# #### **Example**
#
# ```python
# from collections import Counter, defaultdict
#
# # Count occurrences of words in a list of sentences
# sentences = ["hello world", "hello python", "python is great"]
# word_counts = defaultdict(Counter)
#
# for sentence in sentences:
#     words = sentence.split()
#     for word in words:
#         word_counts[word][sentence] += 1
#
# print(word_counts)
# ```
#
# ---
#
# ### **2. Custom Counters**
#
# - You can subclass `Counter` to add custom functionality.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# class MyCounter(Counter):
#     def most_common_above_threshold(self, threshold):
#         return [(k, v) for k, v in self.items() if v > threshold]
#
# counter = MyCounter(a=3, b=2, c=1)
# print(counter.most_common_above_threshold(1))  # Output: [('a', 3), ('b', 2)]
# ```
#
# ---
#
# ## **5. Best Practices**
#
# 1. **Use `Counter` for Counting**:
#
#    - Use `Counter` instead of manually counting elements with dictionaries.
#
# 2. **Leverage Other Collections**:
#
#    - Use `defaultdict`, `deque`, `namedtuple`, etc., when appropriate.
#
# 3. **Combine Collections**:
#
#    - Combine different collections for advanced use cases.
#
# 4. **Document Your Code**:
#    - Add comments or docstrings to explain complex usage of collections.
#
# ---
#
# ## **6. Summary**
#
# - **`Counter`**: A specialized dictionary for counting hashable objects.
# - **Other Collections**:
#   - `defaultdict`: Provides default values for missing keys.
#   - `deque`: A double-ended queue.
#   - `namedtuple`: Creates tuple subclasses with named fields.
#   - `ChainMap`: Combines multiple dictionaries.
#   - `OrderedDict`: Maintains key order.
# - **Advanced Usage**: Combine collections and subclass for custom functionality.
#
# By mastering the `collections` module, you can write more efficient, readable, and maintainable Python code.

# %% [markdown]
# The **`collections` module** in Python provides specialized container datatypes that are alternatives to Python's built-in containers like `list`, `dict`, and `set`. These specialized containers are optimized for specific use cases and offer additional functionality. One of the most commonly used classes in the `collections` module is **`Counter`**, which is used for counting hashable objects.
#
# Below is a comprehensive guide to the `Counter` class and other important classes in the `collections` module, covering everything from basic usage to advanced concepts.
#
# ---
#
# ## **1. Basic Concepts**
#
# ### **What is the `collections` Module?**
#
# - The `collections` module provides alternatives to built-in containers with additional functionality.
# - It includes classes like `Counter`, `defaultdict`, `deque`, `namedtuple`, and `OrderedDict`.
#
# ### **Why Use the `collections` Module?**
#
# - **Efficiency**: Optimized for specific use cases.
# - **Functionality**: Provides additional features not available in built-in containers.
# - **Readability**: Makes code more expressive and concise.
#
# ---
#
# ## **2. The `Counter` Class**
#
# ### **What is `Counter`?**
#
# - `Counter` is a subclass of `dict` designed for counting hashable objects.
# - It stores elements as dictionary keys and their counts as dictionary values.
#
# ### **Basic Syntax**
#
# ```python
# from collections import Counter
#
# counter = Counter(iterable)
# ```
#
# ---
#
# ### **Creating a Counter**
#
# - You can create a `Counter` from an iterable (e.g., list, string) or from keyword arguments.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# # From a list
# counter1 = Counter(['apple', 'banana', 'apple', 'orange'])
# print(counter1)  # Output: Counter({'apple': 2, 'banana': 1, 'orange': 1})
#
# # From a string
# counter2 = Counter("abracadabra")
# print(counter2)  # Output: Counter({'a': 5, 'b': 2, 'r': 2, 'c': 1, 'd': 1})
#
# # From keyword arguments
# counter3 = Counter(apples=3, oranges=5)
# print(counter3)  # Output: Counter({'oranges': 5, 'apples': 3})
# ```
#
# ---
#
# ### **Accessing Counts**
#
# - Use the key to access the count of an element.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter("abracadabra")
# print(counter['a'])  # Output: 5
# print(counter['z'])  # Output: 0 (default for missing keys)
# ```
#
# ---
#
# ### **Updating Counts**
#
# - Use the `update()` method to add counts from another iterable or `Counter`.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter("abracadabra")
# counter.update("apple")
# print(counter)  # Output: Counter({'a': 6, 'b': 2, 'r': 2, 'p': 2, 'c': 1, 'd': 1, 'l': 1, 'e': 1})
# ```
#
# ---
#
# ### **Most Common Elements**
#
# - Use the `most_common(n)` method to get the `n` most common elements.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter("abracadabra")
# print(counter.most_common(2))  # Output: [('a', 5), ('b', 2)]
# ```
#
# ---
#
# ### **Arithmetic Operations**
#
# - You can perform arithmetic operations like addition (`+`), subtraction (`-`), intersection (`&`), and union (`|`) on `Counter` objects.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter1 = Counter("abracadabra")
# counter2 = Counter("apple")
#
# # Addition
# print(counter1 + counter2)  # Output: Counter({'a': 6, 'b': 2, 'r': 2, 'p': 2, 'c': 1, 'd': 1, 'l': 1, 'e': 1})
#
# # Subtraction
# print(counter1 - counter2)  # Output: Counter({'a': 4, 'b': 1, 'r': 2, 'c': 1, 'd': 1})
#
# # Intersection
# print(counter1 & counter2)  # Output: Counter({'a': 1, 'p': 1})
#
# # Union
# print(counter1 | counter2)  # Output: Counter({'a': 5, 'b': 2, 'r': 2, 'p': 1, 'c': 1, 'd': 1, 'l': 1, 'e': 1})
# ```
#
# ---
#
# ### **Removing Zero or Negative Counts**
#
# - Use the `subtract()` method to subtract counts and remove zero or negative counts.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# counter = Counter("abracadabra")
# counter.subtract("apple")
# print(counter)  # Output: Counter({'a': 4, 'b': 1, 'r': 2, 'c': 1, 'd': 1, 'l': -1, 'p': -1, 'e': -1})
#
# # Remove zero or negative counts
# counter += Counter()  # Removes zero or negative counts
# print(counter)  # Output: Counter({'a': 4, 'b': 1, 'r': 2, 'c': 1, 'd': 1})
# ```
#
# ---
#
# ## **3. Other Classes in the `collections` Module**
#
# ### **1. `defaultdict`**
#
# - A subclass of `dict` that provides a default value for missing keys.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Default value is 0
# counter = defaultdict(int)
# for letter in "abracadabra":
#     counter[letter] += 1
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 5, 'b': 2, 'r': 2, 'c': 1, 'd': 1})
# ```
#
# ---
#
# ### **2. `deque`**
#
# - A double-ended queue optimized for fast appends and pops from both ends.
#
# #### **Example**
#
# ```python
# from collections import deque
#
# queue = deque([1, 2, 3])
# queue.append(4)  # Add to the right
# queue.appendleft(0)  # Add to the left
# print(queue)  # Output: deque([0, 1, 2, 3, 4])
#
# queue.pop()  # Remove from the right
# queue.popleft()  # Remove from the left
# print(queue)  # Output: deque([1, 2, 3])
# ```
#
# ---
#
# ### **3. `namedtuple`**
#
# - A factory function for creating tuple subclasses with named fields.
#
# #### **Example**
#
# ```python
# from collections import namedtuple
#
# Point = namedtuple('Point', ['x', 'y'])
# p = Point(10, 20)
# print(p.x, p.y)  # Output: 10 20
# ```
#
# ---
#
# ### **4. `OrderedDict`**
#
# - A subclass of `dict` that maintains the order of keys.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict()
# od['a'] = 1
# od['b'] = 2
# od['c'] = 3
# print(od)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# ```
#
# ---
#
# ## **4. Advanced Usage**
#
# ### **1. Combining `Counter` with Other Classes**
#
# - You can combine `Counter` with other classes like `defaultdict` or `deque` for more advanced use cases.
#
# #### **Example**
#
# ```python
# from collections import Counter, defaultdict
#
# # Count occurrences of each letter in a list of words
# words = ["apple", "banana", "cherry"]
# letter_counts = defaultdict(Counter)
#
# for word in words:
#     letter_counts[len(word)] += Counter(word)
#
# print(letter_counts)  # Output: defaultdict(<class 'collections.Counter'>, {5: Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1, 'b': 1, 'n': 2, 'c': 1, 'h': 1, 'r': 2, 'y': 1})})
# ```
#
# ---
#
# ### **2. Custom Counting Logic**
#
# - You can use `Counter` with custom logic to count specific elements.
#
# #### **Example**
#
# ```python
# from collections import Counter
#
# # Count only even numbers
# numbers = [1, 2, 3, 4, 5, 6]
# even_counter = Counter(x for x in numbers if x % 2 == 0)
# print(even_counter)  # Output: Counter({2: 1, 4: 1, 6: 1})
# ```
#
# ---
#
# ## **5. Best Practices**
#
# 1. **Use `Counter` for Counting**:
#
#    - Use `Counter` instead of manually counting elements with a dictionary.
#
# 2. **Leverage `defaultdict` for Default Values**:
#
#    - Use `defaultdict` when you need default values for missing keys.
#
# 3. **Use `deque` for Queues and Stacks**:
#
#    - Use `deque` for efficient appends and pops from both ends.
#
# 4. **Use `namedtuple` for Readable Tuples**:
#
#    - Use `namedtuple` when you need tuples with named fields.
#
# 5. **Use `OrderedDict` for Ordered Dictionaries**:
#    - Use `OrderedDict` when you need to maintain the order of keys.
#
# ---
#
# ## **6. Summary**
#
# - **`Counter`**: Used for counting hashable objects.
# - **`defaultdict`**: Provides default values for missing keys.
# - **`deque`**: A double-ended queue for fast appends and pops.
# - **`namedtuple`**: Creates tuple subclasses with named fields.
# - **`OrderedDict`**: Maintains the order of keys in a dictionary.
#
# By mastering the `collections` module, you can write more efficient, readable, and expressive Python code.

# %% [markdown]
# The **`defaultdict`** class in Python is part of the `collections` module. It is a subclass of the built-in `dict` class that provides a default value for missing keys. This is particularly useful when working with dictionaries where you want to avoid key errors and simplify code by automatically initializing values for new keys.
#
# Below is a comprehensive guide to `defaultdict`, covering everything from basic usage to advanced concepts.
#
# ---
#
# ## **1. Basic Concepts**
#
# ### **What is `defaultdict`?**
#
# - `defaultdict` is a dictionary subclass that provides a default value for missing keys.
# - It takes a factory function (e.g., `int`, `list`, `set`) as an argument, which is used to generate default values.
#
# ### **Why Use `defaultdict`?**
#
# - **Avoid Key Errors**: Automatically initializes values for missing keys.
# - **Simplify Code**: Reduces the need for explicit checks and initializations.
# - **Flexibility**: Works with any callable factory function.
#
# ---
#
# ## **2. Basic Usage**
#
# ### **Creating a `defaultdict`**
#
# - You can create a `defaultdict` by passing a factory function to it.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Default value is 0 (using int as the factory function)
# counter = defaultdict(int)
#
# # Default value is an empty list (using list as the factory function)
# grouped_data = defaultdict(list)
#
# # Default value is an empty set (using set as the factory function)
# unique_items = defaultdict(set)
# ```
#
# ---
#
# ### **Adding Items**
#
# - You can add items to a `defaultdict` just like a regular dictionary.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Using int as the factory function
# counter = defaultdict(int)
# counter['a'] += 1
# counter['b'] += 2
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'b': 2})
#
# # Using list as the factory function
# grouped_data = defaultdict(list)
# grouped_data['fruits'].append('apple')
# grouped_data['fruits'].append('banana')
# grouped_data['vegetables'].append('carrot')
# print(grouped_data)  # Output: defaultdict(<class 'list'>, {'fruits': ['apple', 'banana'], 'vegetables': ['carrot']})
# ```
#
# ---
#
# ### **Accessing Items**
#
# - You can access items in a `defaultdict` using keys, just like a regular dictionary.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int)
# counter['a'] = 1
# print(counter['a'])  # Output: 1
# print(counter['b'])  # Output: 0 (default value for missing key)
# ```
#
# ---
#
# ### **Iterating Over a `defaultdict`**
#
# - You can iterate over the keys, values, or items of a `defaultdict` just like a regular dictionary.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# grouped_data = defaultdict(list)
# grouped_data['fruits'].append('apple')
# grouped_data['fruits'].append('banana')
# grouped_data['vegetables'].append('carrot')
#
# # Iterate over keys
# for key in grouped_data:
#     print(key, end=" ")  # Output: fruits vegetables
#
# # Iterate over values
# for value in grouped_data.values():
#     print(value, end=" ")  # Output: ['apple', 'banana'] ['carrot']
#
# # Iterate over items
# for key, value in grouped_data.items():
#     print(f"{key}: {value}", end=" ")  # Output: fruits: ['apple', 'banana'] vegetables: ['carrot']
# ```
#
# ---
#
# ### **Updating Items**
#
# - You can update the value of an existing key or add new key-value pairs using the `update()` method.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int)
# counter.update({'a': 1, 'b': 2})
# counter.update({'b': 20, 'c': 3})
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'b': 20, 'c': 3})
# ```
#
# ---
#
# ### **Deleting Items**
#
# - You can delete items using the `del` statement or the `pop()` method.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int, {'a': 1, 'b': 2, 'c': 3})
#
# # Using del
# del counter['b']
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'c': 3})
#
# # Using pop
# counter.pop('a')
# print(counter)  # Output: defaultdict(<class 'int'>, {'c': 3})
# ```
#
# ---
#
# ## **3. Advanced Usage**
#
# ### **1. Custom Default Values**
#
# - You can use a custom function as the factory to generate default values.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Custom factory function
# def default_value():
#     return "Unknown"
#
# data = defaultdict(default_value)
# print(data['name'])  # Output: Unknown
# ```
#
# ---
#
# ### **2. Nested `defaultdict`**
#
# - You can create nested `defaultdict` objects for more complex data structures.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Nested defaultdict
# nested_data = defaultdict(lambda: defaultdict(int))
# nested_data['a']['x'] += 1
# nested_data['a']['y'] += 2
# nested_data['b']['x'] += 3
# print(nested_data)  # Output: defaultdict(<function <lambda> at 0x...>, {'a': defaultdict(<class 'int'>, {'x': 1, 'y': 2}), 'b': defaultdict(<class 'int'>, {'x': 3})})
# ```
#
# ---
#
# ### **3. Combining `defaultdict` with Other Collections**
#
# - You can combine `defaultdict` with other collections like `Counter` or `deque` for advanced use cases.
#
# #### **Example**
#
# ```python
# from collections import defaultdict, Counter
#
# # Count occurrences of each letter in a list of words
# words = ["apple", "banana", "cherry"]
# letter_counts = defaultdict(Counter)
#
# for word in words:
#     letter_counts[len(word)] += Counter(word)
#
# print(letter_counts)  # Output: defaultdict(<class 'collections.Counter'>, {5: Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1, 'b': 1, 'n': 2, 'c': 1, 'h': 1, 'r': 2, 'y': 1})})
# ```
#
# ---
#
# ### **4. Using `defaultdict` with JSON**
#
# - `defaultdict` can be used to simplify the creation of nested JSON-like structures.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
# import json
#
# # Create a nested defaultdict
# data = defaultdict(lambda: defaultdict(dict))
# data['user']['profile']['name'] = "Alice"
# data['user']['profile']['age'] = 30
#
# # Convert to JSON
# print(json.dumps(data, indent=4))
# ```
#
# **Output:**
#
# ```json
# {
#   "user": {
#     "profile": {
#       "name": "Alice",
#       "age": 30
#     }
#   }
# }
# ```
#
# ---
#
# ## **4. Best Practices**
#
# 1. **Use `defaultdict` for Missing Keys**:
#
#    - Use `defaultdict` when you want to avoid key errors and automatically initialize values.
#
# 2. **Choose the Right Factory Function**:
#
#    - Use appropriate factory functions like `int`, `list`, `set`, or custom functions.
#
# 3. **Avoid Overwriting Defaults**:
#
#    - Be cautious when updating keys, as it may overwrite the default value.
#
# 4. **Combine with Other Collections**:
#
#    - Combine `defaultdict` with other collections like `Counter` or `deque` for advanced use cases.
#
# 5. **Document Custom Factory Functions**:
#    - Clearly document custom factory functions to make the code more readable.
#
# ---
#
# ## **5. Summary**
#
# - **`defaultdict`**: A dictionary subclass that provides default values for missing keys.
# - **Basic Operations**: Adding, accessing, updating, and deleting items.
# - **Advanced Usage**: Custom default values, nested `defaultdict`, combining with other collections, and JSON-like structures.
# - **Best Practices**: Use for missing keys, choose the right factory function, and combine with other collections.
#
# By mastering `defaultdict`, you can simplify your code and handle missing keys more gracefully, making your programs more robust and maintainable.

# %% [markdown]
# The **`defaultdict`** class in Python is part of the `collections` module. It is a subclass of the built-in `dict` class that provides a default value for missing keys. This is particularly useful when working with dictionaries where you want to avoid key errors and simplify code by automatically initializing values for new keys.
#
# Below is a comprehensive guide to `defaultdict`, covering everything from basic syntax to advanced usage.
#
# ---
#
# ## **1. Basic Syntax**
#
# ### **Importing `defaultdict`**
#
# - To use `defaultdict`, you need to import it from the `collections` module.
#
# ```python
# from collections import defaultdict
# ```
#
# ---
#
# ### **Creating a `defaultdict`**
#
# - You can create a `defaultdict` by passing a **factory function** to it. The factory function is called to provide a default value for missing keys.
#
# #### **Syntax**
#
# ```python
# defaultdict(factory_function)
# ```
#
# - **`factory_function`**: A callable (e.g., `int`, `list`, `set`, or a custom function) that returns the default value for missing keys.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Default value is 0 (using int as the factory function)
# counter = defaultdict(int)
#
# # Default value is an empty list (using list as the factory function)
# grouped_data = defaultdict(list)
#
# # Default value is an empty set (using set as the factory function)
# unique_items = defaultdict(set)
# ```
#
# ---
#
# ### **Adding Items**
#
# - You can add items to a `defaultdict` just like a regular dictionary.
#
# #### **Syntax**
#
# ```python
# defaultdict[key] = value
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Using int as the factory function
# counter = defaultdict(int)
# counter['a'] += 1
# counter['b'] += 2
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'b': 2})
#
# # Using list as the factory function
# grouped_data = defaultdict(list)
# grouped_data['fruits'].append('apple')
# grouped_data['fruits'].append('banana')
# grouped_data['vegetables'].append('carrot')
# print(grouped_data)  # Output: defaultdict(<class 'list'>, {'fruits': ['apple', 'banana'], 'vegetables': ['carrot']})
# ```
#
# ---
#
# ### **Accessing Items**
#
# - You can access items in a `defaultdict` using keys, just like a regular dictionary.
#
# #### **Syntax**
#
# ```python
# defaultdict[key]
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int)
# counter['a'] = 1
# print(counter['a'])  # Output: 1
# print(counter['b'])  # Output: 0 (default value for missing key)
# ```
#
# ---
#
# ### **Iterating Over a `defaultdict`**
#
# - You can iterate over the keys, values, or items of a `defaultdict` just like a regular dictionary.
#
# #### **Syntax**
#
# ```python
# for key in defaultdict:
#     pass
#
# for value in defaultdict.values():
#     pass
#
# for key, value in defaultdict.items():
#     pass
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# grouped_data = defaultdict(list)
# grouped_data['fruits'].append('apple')
# grouped_data['fruits'].append('banana')
# grouped_data['vegetables'].append('carrot')
#
# # Iterate over keys
# for key in grouped_data:
#     print(key, end=" ")  # Output: fruits vegetables
#
# # Iterate over values
# for value in grouped_data.values():
#     print(value, end=" ")  # Output: ['apple', 'banana'] ['carrot']
#
# # Iterate over items
# for key, value in grouped_data.items():
#     print(f"{key}: {value}", end=" ")  # Output: fruits: ['apple', 'banana'] vegetables: ['carrot']
# ```
#
# ---
#
# ### **Updating Items**
#
# - You can update the value of an existing key or add new key-value pairs using the `update()` method.
#
# #### **Syntax**
#
# ```python
# defaultdict.update(other_dict)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int)
# counter.update({'a': 1, 'b': 2})
# counter.update({'b': 20, 'c': 3})
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'b': 20, 'c': 3})
# ```
#
# ---
#
# ### **Deleting Items**
#
# - You can delete items using the `del` statement or the `pop()` method.
#
# #### **Syntax**
#
# ```python
# del defaultdict[key]
# defaultdict.pop(key)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int, {'a': 1, 'b': 2, 'c': 3})
#
# # Using del
# del counter['b']
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'c': 3})
#
# # Using pop
# counter.pop('a')
# print(counter)  # Output: defaultdict(<class 'int'>, {'c': 3})
# ```
#
# ---
#
# ## **2. Advanced Syntax**
#
# ### **1. Custom Default Values**
#
# - You can use a custom function as the factory to generate default values.
#
# #### **Syntax**
#
# ```python
# defaultdict(custom_function)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Custom factory function
# def default_value():
#     return "Unknown"
#
# data = defaultdict(default_value)
# print(data['name'])  # Output: Unknown
# ```
#
# ---
#
# ### **2. Nested `defaultdict`**
#
# - You can create nested `defaultdict` objects for more complex data structures.
#
# #### **Syntax**
#
# ```python
# defaultdict(lambda: defaultdict(factory_function))
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Nested defaultdict
# nested_data = defaultdict(lambda: defaultdict(int))
# nested_data['a']['x'] += 1
# nested_data['a']['y'] += 2
# nested_data['b']['x'] += 3
# print(nested_data)  # Output: defaultdict(<function <lambda> at 0x...>, {'a': defaultdict(<class 'int'>, {'x': 1, 'y': 2}), 'b': defaultdict(<class 'int'>, {'x': 3})})
# ```
#
# ---
#
# ### **3. Combining `defaultdict` with Other Collections**
#
# - You can combine `defaultdict` with other collections like `Counter` or `deque` for advanced use cases.
#
# #### **Example**
#
# ```python
# from collections import defaultdict, Counter
#
# # Count occurrences of each letter in a list of words
# words = ["apple", "banana", "cherry"]
# letter_counts = defaultdict(Counter)
#
# for word in words:
#     letter_counts[len(word)] += Counter(word)
#
# print(letter_counts)  # Output: defaultdict(<class 'collections.Counter'>, {5: Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1, 'b': 1, 'n': 2, 'c': 1, 'h': 1, 'r': 2, 'y': 1})})
# ```
#
# ---
#
# ### **4. Using `defaultdict` with JSON**
#
# - `defaultdict` can be used to simplify the creation of nested JSON-like structures.
#
# #### **Example**
#
# ```python
# from collections import defaultdict
# import json
#
# # Create a nested defaultdict
# data = defaultdict(lambda: defaultdict(dict))
# data['user']['profile']['name'] = "Alice"
# data['user']['profile']['age'] = 30
#
# # Convert to JSON
# print(json.dumps(data, indent=4))
# ```
#
# **Output:**
#
# ```json
# {
#   "user": {
#     "profile": {
#       "name": "Alice",
#       "age": 30
#     }
#   }
# }
# ```
#
# ---
#
# ## **3. Best Practices**
#
# 1. **Use `defaultdict` for Missing Keys**:
#
#    - Use `defaultdict` when you want to avoid key errors and automatically initialize values.
#
# 2. **Choose the Right Factory Function**:
#
#    - Use appropriate factory functions like `int`, `list`, `set`, or custom functions.
#
# 3. **Avoid Overwriting Defaults**:
#
#    - Be cautious when updating keys, as it may overwrite the default value.
#
# 4. **Combine with Other Collections**:
#
#    - Combine `defaultdict` with other collections like `Counter` or `deque` for advanced use cases.
#
# 5. **Document Custom Factory Functions**:
#    - Clearly document custom factory functions to make the code more readable.
#
# ---
#
# ## **4. Summary**
#
# - **`defaultdict`**: A dictionary subclass that provides default values for missing keys.
# - **Basic Syntax**: Creating, adding, accessing, updating, and deleting items.
# - **Advanced Syntax**: Custom default values, nested `defaultdict`, combining with other collections, and JSON-like structures.
# - **Best Practices**: Use for missing keys, choose the right factory function, and combine with other collections.
#
# By mastering `defaultdict`, you can simplify your code and handle missing keys more gracefully, making your programs more robust and maintainable.

# %% [markdown]
# The **`defaultdict`** class in Python is part of the `collections` module. It is a subclass of the built-in `dict` class that provides a default value for missing keys. This is particularly useful when working with dictionaries where you want to avoid key errors and simplify code by automatically initializing values for new keys.
#
# Below is a comprehensive guide to `defaultdict`, covering everything from basic syntax to advanced usage.
#
# ---
#
# ## **1. Basic Syntax**
#
# ### **Importing `defaultdict`**
#
# - To use `defaultdict`, you need to import it from the `collections` module.
#
# ```python
# from collections import defaultdict
# ```
#
# ---
#
# ### **Creating a `defaultdict`**
#
# - You can create a `defaultdict` by passing a factory function to it. The factory function specifies the default value for missing keys.
#
# #### **Syntax**
#
# ```python
# defaultdict(factory_function)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Default value is 0 (using int as the factory function)
# counter = defaultdict(int)
#
# # Default value is an empty list (using list as the factory function)
# grouped_data = defaultdict(list)
#
# # Default value is an empty set (using set as the factory function)
# unique_items = defaultdict(set)
# ```
#
# ---
#
# ### **Adding Items**
#
# - You can add items to a `defaultdict` just like a regular dictionary.
#
# #### **Syntax**
#
# ```python
# defaultdict[key] = value
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Using int as the factory function
# counter = defaultdict(int)
# counter['a'] += 1
# counter['b'] += 2
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'b': 2})
#
# # Using list as the factory function
# grouped_data = defaultdict(list)
# grouped_data['fruits'].append('apple')
# grouped_data['fruits'].append('banana')
# grouped_data['vegetables'].append('carrot')
# print(grouped_data)  # Output: defaultdict(<class 'list'>, {'fruits': ['apple', 'banana'], 'vegetables': ['carrot']})
# ```
#
# ---
#
# ### **Accessing Items**
#
# - You can access items in a `defaultdict` using keys, just like a regular dictionary.
#
# #### **Syntax**
#
# ```python
# value = defaultdict[key]
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int)
# counter['a'] = 1
# print(counter['a'])  # Output: 1
# print(counter['b'])  # Output: 0 (default value for missing key)
# ```
#
# ---
#
# ### **Iterating Over a `defaultdict`**
#
# - You can iterate over the keys, values, or items of a `defaultdict` just like a regular dictionary.
#
# #### **Syntax**
#
# ```python
# for key in defaultdict:
#     # Access keys
#
# for value in defaultdict.values():
#     # Access values
#
# for key, value in defaultdict.items():
#     # Access items
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# grouped_data = defaultdict(list)
# grouped_data['fruits'].append('apple')
# grouped_data['fruits'].append('banana')
# grouped_data['vegetables'].append('carrot')
#
# # Iterate over keys
# for key in grouped_data:
#     print(key, end=" ")  # Output: fruits vegetables
#
# # Iterate over values
# for value in grouped_data.values():
#     print(value, end=" ")  # Output: ['apple', 'banana'] ['carrot']
#
# # Iterate over items
# for key, value in grouped_data.items():
#     print(f"{key}: {value}", end=" ")  # Output: fruits: ['apple', 'banana'] vegetables: ['carrot']
# ```
#
# ---
#
# ### **Updating Items**
#
# - You can update the value of an existing key or add new key-value pairs using the `update()` method.
#
# #### **Syntax**
#
# ```python
# defaultdict.update(other_dict)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int)
# counter.update({'a': 1, 'b': 2})
# counter.update({'b': 20, 'c': 3})
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'b': 20, 'c': 3})
# ```
#
# ---
#
# ### **Deleting Items**
#
# - You can delete items using the `del` statement or the `pop()` method.
#
# #### **Syntax**
#
# ```python
# del defaultdict[key]
# defaultdict.pop(key)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# counter = defaultdict(int, {'a': 1, 'b': 2, 'c': 3})
#
# # Using del
# del counter['b']
# print(counter)  # Output: defaultdict(<class 'int'>, {'a': 1, 'c': 3})
#
# # Using pop
# counter.pop('a')
# print(counter)  # Output: defaultdict(<class 'int'>, {'c': 3})
# ```
#
# ---
#
# ## **2. Advanced Syntax**
#
# ### **1. Custom Default Values**
#
# - You can use a custom function as the factory to generate default values.
#
# #### **Syntax**
#
# ```python
# defaultdict(custom_function)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Custom factory function
# def default_value():
#     return "Unknown"
#
# data = defaultdict(default_value)
# print(data['name'])  # Output: Unknown
# ```
#
# ---
#
# ### **2. Nested `defaultdict`**
#
# - You can create nested `defaultdict` objects for more complex data structures.
#
# #### **Syntax**
#
# ```python
# defaultdict(lambda: defaultdict(factory_function))
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
#
# # Nested defaultdict
# nested_data = defaultdict(lambda: defaultdict(int))
# nested_data['a']['x'] += 1
# nested_data['a']['y'] += 2
# nested_data['b']['x'] += 3
# print(nested_data)  # Output: defaultdict(<function <lambda> at 0x...>, {'a': defaultdict(<class 'int'>, {'x': 1, 'y': 2}), 'b': defaultdict(<class 'int'>, {'x': 3})})
# ```
#
# ---
#
# ### **3. Combining `defaultdict` with Other Collections**
#
# - You can combine `defaultdict` with other collections like `Counter` or `deque` for advanced use cases.
#
# #### **Syntax**
#
# ```python
# defaultdict(Counter)
# defaultdict(deque)
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict, Counter
#
# # Count occurrences of each letter in a list of words
# words = ["apple", "banana", "cherry"]
# letter_counts = defaultdict(Counter)
#
# for word in words:
#     letter_counts[len(word)] += Counter(word)
#
# print(letter_counts)  # Output: defaultdict(<class 'collections.Counter'>, {5: Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1, 'b': 1, 'n': 2, 'c': 1, 'h': 1, 'r': 2, 'y': 1})})
# ```
#
# ---
#
# ### **4. Using `defaultdict` with JSON**
#
# - `defaultdict` can be used to simplify the creation of nested JSON-like structures.
#
# #### **Syntax**
#
# ```python
# defaultdict(lambda: defaultdict(dict))
# ```
#
# #### **Example**
#
# ```python
# from collections import defaultdict
# import json
#
# # Create a nested defaultdict
# data = defaultdict(lambda: defaultdict(dict))
# data['user']['profile']['name'] = "Alice"
# data['user']['profile']['age'] = 30
#
# # Convert to JSON
# print(json.dumps(data, indent=4))
# ```
#
# **Output:**
#
# ```json
# {
#   "user": {
#     "profile": {
#       "name": "Alice",
#       "age": 30
#     }
#   }
# }
# ```
#
# ---
#
# ## **3. Best Practices**
#
# 1. **Use `defaultdict` for Missing Keys**:
#
#    - Use `defaultdict` when you want to avoid key errors and automatically initialize values.
#
# 2. **Choose the Right Factory Function**:
#
#    - Use appropriate factory functions like `int`, `list`, `set`, or custom functions.
#
# 3. **Avoid Overwriting Defaults**:
#
#    - Be cautious when updating keys, as it may overwrite the default value.
#
# 4. **Combine with Other Collections**:
#
#    - Combine `defaultdict` with other collections like `Counter` or `deque` for advanced use cases.
#
# 5. **Document Custom Factory Functions**:
#    - Clearly document custom factory functions to make the code more readable.
#
# ---
#
# ## **4. Summary**
#
# - **`defaultdict`**: A dictionary subclass that provides default values for missing keys.
# - **Basic Syntax**: Creating, adding, accessing, updating, and deleting items.
# - **Advanced Syntax**: Custom default values, nested `defaultdict`, combining with other collections, and JSON-like structures.
# - **Best Practices**: Use for missing keys, choose the right factory function, and combine with other collections.
#
# By mastering `defaultdict`, you can simplify your code and handle missing keys more gracefully, making your programs more robust and maintainable.

# %% [markdown]
# The **`OrderedDict`** class in Python is part of the `collections` module. It is a subclass of the built-in `dict` class that maintains the order of keys as they are inserted. This is particularly useful when the order of insertion is important, such as when implementing LRU (Least Recently Used) caches or maintaining a specific sequence of elements.
#
# Below is a comprehensive guide to `OrderedDict`, covering everything from basic usage to advanced concepts.
#
# ---
#
# ## **1. Basic Concepts**
#
# ### **What is `OrderedDict`?**
#
# - `OrderedDict` is a dictionary subclass that remembers the order in which items were inserted.
# - It maintains a doubly-linked list to keep track of the order of keys.
#
# ### **Why Use `OrderedDict`?**
#
# - **Order Preservation**: Maintains the order of keys as they are inserted.
# - **LRU Cache**: Useful for implementing LRU caches.
# - **Predictable Iteration**: Ensures consistent iteration order.
#
# ---
#
# ## **2. Basic Usage**
#
# ### **Creating an `OrderedDict`**
#
# - You can create an `OrderedDict` from a sequence of key-value pairs or from another dictionary.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# # From a list of tuples
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# print(od)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3)])
#
# # From a dictionary
# od = OrderedDict({'a': 1, 'b': 2, 'c': 3})
# print(od)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# ```
#
# ---
#
# ### **Adding Items**
#
# - You can add items to an `OrderedDict` just like a regular dictionary.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict()
# od['a'] = 1
# od['b'] = 2
# od['c'] = 3
# print(od)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# ```
#
# ---
#
# ### **Accessing Items**
#
# - You can access items in an `OrderedDict` using keys, just like a regular dictionary.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# print(od['a'])  # Output: 1
# ```
#
# ---
#
# ### **Iterating Over an `OrderedDict`**
#
# - You can iterate over the keys, values, or items of an `OrderedDict` while maintaining the insertion order.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
#
# # Iterate over keys
# for key in od:
#     print(key, end=" ")  # Output: a b c
#
# # Iterate over values
# for value in od.values():
#     print(value, end=" ")  # Output: 1 2 3
#
# # Iterate over items
# for key, value in od.items():
#     print(f"{key}: {value}", end=" ")  # Output: a: 1 b: 2 c: 3
# ```
#
# ---
#
# ### **Updating Items**
#
# - You can update the value of an existing key or add new key-value pairs using the `update()` method.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
# od.update({'b': 20, 'd': 4})
# print(od)  # Output: OrderedDict([('a', 1), ('b', 20), ('c', 3), ('d', 4)])
# ```
#
# ---
#
# ### **Deleting Items**
#
# - You can delete items using the `del` statement or the `pop()` method.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
#
# # Using del
# del od['b']
# print(od)  # Output: OrderedDict([('a', 1), ('c', 3)])
#
# # Using pop
# od.pop('a')
# print(od)  # Output: OrderedDict([('c', 3)])
# ```
#
# ---
#
# ## **3. Advanced Usage**
#
# ### **1. Reordering Items**
#
# - You can move an item to the beginning or end of the `OrderedDict` using the `move_to_end()` method.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
#
# # Move 'b' to the end
# od.move_to_end('b')
# print(od)  # Output: OrderedDict([('a', 1), ('c', 3), ('b', 2)])
#
# # Move 'a' to the beginning
# od.move_to_end('a', last=False)
# print(od)  # Output: OrderedDict([('a', 1), ('c', 3), ('b', 2)])
# ```
#
# ---
#
# ### **2. Reversing an `OrderedDict`**
#
# - You can reverse the order of items in an `OrderedDict` using the `reversed()` function.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
#
# # Reverse the order
# reversed_od = OrderedDict(reversed(od.items()))
# print(reversed_od)  # Output: OrderedDict([('c', 3), ('b', 2), ('a', 1)])
# ```
#
# ---
#
# ### **3. Merging `OrderedDict` Objects**
#
# - You can merge two `OrderedDict` objects while preserving the order.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# od1 = OrderedDict([('a', 1), ('b', 2)])
# od2 = OrderedDict([('c', 3), ('d', 4)])
#
# # Merge od2 into od1
# od1.update(od2)
# print(od1)  # Output: OrderedDict([('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# ```
#
# ---
#
# ### **4. Implementing an LRU Cache**
#
# - `OrderedDict` is commonly used to implement an LRU (Least Recently Used) cache.
#
# #### **Example**
#
# ```python
# from collections import OrderedDict
#
# class LRUCache:
#     def __init__(self, capacity: int):
#         self.cache = OrderedDict()
#         self.capacity = capacity
#
#     def get(self, key: int) -> int:
#         if key not in self.cache:
#             return -1
#         else:
#             self.cache.move_to_end(key)
#             return self.cache[key]
#
#     def put(self, key: int, value: int) -> None:
#         if key in self.cache:
#             self.cache.move_to_end(key)
#         self.cache[key] = value
#         if len(self.cache) > self.capacity:
#             self.cache.popitem(last=False)
#
# # Usage
# lru_cache = LRUCache(2)
# lru_cache.put(1, 1)
# lru_cache.put(2, 2)
# print(lru_cache.get(1))  # Output: 1
# lru_cache.put(3, 3)
# print(lru_cache.get(2))  # Output: -1
# ```
#
# ---
#
# ## **4. Best Practices**
#
# 1. **Use `OrderedDict` for Order Preservation**:
#
#    - Use `OrderedDict` when the order of insertion is important.
#
# 2. **Avoid Overwriting Keys**:
#
#    - Be cautious when updating keys, as it may affect the order.
#
# 3. **Use `move_to_end()` for Reordering**:
#
#    - Use `move_to_end()` to efficiently reorder items.
#
# 4. **Leverage `OrderedDict` for LRU Caches**:
#
#    - Use `OrderedDict` to implement LRU caches efficiently.
#
# 5. **Combine with Other Collections**:
#    - Combine `OrderedDict` with other collections like `defaultdict` or `Counter` for advanced use cases.
#
# ---
#
# ## **5. Summary**
#
# - **`OrderedDict`**: A dictionary subclass that maintains insertion order.
# - **Basic Operations**: Adding, accessing, updating, and deleting items.
# - **Advanced Usage**: Reordering items, reversing, merging, and implementing LRU caches.
# - **Best Practices**: Use for order preservation, avoid overwriting keys, and leverage for LRU caches.
#
# By mastering `OrderedDict`, you can handle scenarios where the order of elements is crucial, making your code more predictable and efficient.
